# %%
import pandas as pd

from pathlib import Path

# %%
#test_data_dict_2[symbol]['companyProfile']['isEtf']

# %%
## Load pickle for exports and imports of data  
import pickle 
def load_obj(path):
    with open(path, 'rb') as f:
        return pickle.load(f)
    
def save_obj(obj, path ):
    with open(path, 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

# %%
import_path = '../Resources/symbol_success_list_new.pkl'
datadict_success_list = load_obj(import_path)

len(datadict_success_list)
# Out:
# 5493

# %%
dataframe = pd.DataFrame()
new_symbol_list = []

for symbol in datadict_success_list:
    import_path = '../FilesExport_Complete_DataDicts_2/'+symbol+'_updated_data_dict.pkl'
    import_data = load_obj(import_path)
    
    data = import_data[symbol]['ftd_stats']
    try:
        data['isEtf'] = import_data[symbol]['companyProfile']['isEtf'] 
    except:
        continue

    empty_dict = {}
    empty_dict[symbol] = data
       
    if symbol == 0:
        dataframe = pd.DataFrame.from_dict(empty_dict,orient='index')
    else: 
        dataframe2 = pd.DataFrame.from_dict(empty_dict,orient='index')
        dataframe = dataframe.append(dataframe2)
        
    new_symbol_list.append(symbol)
        

## Keep only FTD related columns (drop volume data)
dataframe = dataframe[['total_ftds_all','total_ftds_2021','total_ftds_ytd','total_ftds_month',
                      'os_ftd_pct_all','os_ftd_pct_2021','os_ftd_pct_ytd','os_ftd_pct_month',
                      'float_ftd_pct_all','float_ftd_pct_2021','float_ftd_pct_ytd','float_ftd_pct_month',
                      'isEtf']]
        
len(dataframe)
# Out:
# 5478

# %%
etf_df = dataframe[dataframe['isEtf'] == True]
len(etf_df)
# Out:
# 1297

# %%
stock_df = dataframe[dataframe['isEtf'] == False]
len(stock_df)
# Out:
# 4181

# %%
## Stocks 

## Sort All-Time fails 
stock_df.sort_values('float_ftd_pct_all',ascending=False).head()
# Out:
#       total_ftds_all  total_ftds_2021  total_ftds_ytd  total_ftds_month  \
# BTCS     500095929.0        3852932.0       3505330.0         2259651.0
# DCTH     147717003.0         777884.0        723240.0           38013.0
# JRJC       2244063.0         924438.0        853942.0           11142.0
# NXTD      78318932.0       18147872.0      12215845.0               0.0
# IDXG      28803322.0              0.0             0.0               0.0
#
#       os_ftd_pct_all  os_ftd_pct_2021  os_ftd_pct_ytd  os_ftd_pct_month  \
# BTCS     4840.082686        37.289865       33.925665         21.869600
# DCTH     1932.513246        10.176697        9.461814          0.497307
# JRJC       87.770035        36.156719       33.399472          0.435787
# NXTD      840.195131       194.687968      131.049968          0.000000
# IDXG      682.107564         0.000000        0.000000          0.000000
#
#       float_ftd_pct_all  float_ftd_pct_2021  float_ftd_pct_ytd  \
# ...

# %%
## Sort Highest fails since start of 2021 
stock_df.sort_values('float_ftd_pct_2021',ascending=False).head()
# Out:
#       total_ftds_all  total_ftds_2021  total_ftds_ytd  total_ftds_month  \
# INDP      17939142.0       17939142.0      17939142.0           65512.0
# JRJC       2244063.0         924438.0        853942.0           11142.0
# CELZ      14840228.0        7825615.0       7745550.0          649818.0
# ISIG       5807135.0        3699903.0       3653300.0          701638.0
# CYRN      12022239.0        9904101.0       9822147.0          100135.0
#
#       os_ftd_pct_all  os_ftd_pct_2021  os_ftd_pct_ytd  os_ftd_pct_month  \
# INDP      215.965242       215.965242      215.965242          0.788684
# JRJC       87.770035        36.156719       33.399472          0.435787
# CELZ      195.406156       103.042443      101.988201          8.556367
# ISIG      325.169566       207.175458      204.565931         39.288104
# CYRN       13.161719        10.842822       10.753100          0.109626
#
#       float_ftd_pct_all  float_ftd_pct_2021  float_ftd_pct_ytd  \
# ...

# %%
## Sort Highest fails year-to-date
stock_df.sort_values('float_ftd_pct_ytd',ascending=False).head()
# Out:
#       total_ftds_all  total_ftds_2021  total_ftds_ytd  total_ftds_month  \
# INDP      17939142.0       17939142.0      17939142.0           65512.0
# JRJC       2244063.0         924438.0        853942.0           11142.0
# CELZ      14840228.0        7825615.0       7745550.0          649818.0
# ISIG       5807135.0        3699903.0       3653300.0          701638.0
# CYRN      12022239.0        9904101.0       9822147.0          100135.0
#
#       os_ftd_pct_all  os_ftd_pct_2021  os_ftd_pct_ytd  os_ftd_pct_month  \
ascending=False).head()
# Out:
#       total_ftds_all  total_ftds_2021  total_ftds_ytd  total_ftds_month  \
# HMNY    1.183597e+09       15723172.0      15013744.0               0.0
# SPY     8.447101e+08      109990037.0     108382334.0         4345419.0
# IWM     8.060305e+08       95131163.0      94052164.0         7083965.0
# QQQ     7.990482e+08       92801914.0      89898699.0        12757809.0
# EEM     6.764395e+08       92850307.0      86799215.0         6815451.0
#
#       os_ftd_pct_all  os_ftd_pct_2021  os_ftd_pct_ytd  os_ftd_pct_month  \
# HMNY       56.466674         0.750116        0.716271          0.000000
# SPY        90.874315        11.832780       11.659823          0.467482
# IWM       259.648381        30.644811       30.297230          2.281973
# QQQ       145.389357        16.885602       16.357353          2.321324
# EEM       109.628878        15.048020       14.067335          1.104563
#
#       float_ftd_pct_all  float_ftd_pct_2021  float_ftd_pct_ytd  \
# ...

# %%
## Sort All-Time fails 
dataframe.sort_values('os_ftd_pct_all',ascending=False).head()
# Out:
#        total_ftds_all  total_ftds_2021  total_ftds_ytd  total_ftds_month  \
# SPCB       11516278.0        5794201.0       4185627.0          289659.0
# LABD      107708132.0       18513991.0      18176201.0         1191758.0
# DUST      392072333.0       17120059.0      14203484.0          562171.0
# XRT       365970061.0       55298947.0      52243262.0         4104269.0
# CYCCP         67173.0           5555.0          4109.0             690.0
#
#        os_ftd_pct_all  os_ftd_pct_2021  os_ftd_pct_ytd  os_ftd_pct_month  \
# SPCB     57240.807197     28799.647100    20804.349123       1439.728615
# LABD      6940.386261      1192.985584     1171.219418         76.793281
# DUST      6371.979077       278.236051      230.835729          9.136431
# XRT       5223.339003       789.258952      745.646426         58.578530
# CYCCP     5167.153846       427.307692      316.076923         53.076923
#
#        float_ftd_pct_all  float_ftd_pct_2021  float_ftd_pct_ytd  \
# ...

# %%
## Sort Highest fails since start of 2021 
dataframe.sort_values('os_ftd_pct_2021',ascending=False).head()
# Out:
#       total_ftds_all  total_ftds_2021  total_ftds_ytd  total_ftds_month  \
# SPCB      11516278.0        5794201.0       4185627.0          289659.0
# LABD     107708132.0       18513991.0      18176201.0         1191758.0
# XRT      365970061.0       55298947.0      52243262.0         4104269.0
# UJB        1152446.0         689579.0        622710.0           67831.0
# SRTY      57194845.0       17910592.0      17007924.0          463826.0
#
#       os_ftd_pct_all  os_ftd_pct_2021  os_ftd_pct_ytd  os_ftd_pct_month  \
# SPCB    57240.807197     28799.647100    20804.349123       1439.728615
# LABD     6940.386261      1192.985584     1171.219418         76.793281
# XRT      5223.339003       789.258952      745.646426         58.578530
# UJB      1131.746359       677.193138      611.525204         66.612655
# SRTY     1557.179503       487.631477      463.055554         12.628067
#
#       float_ftd_pct_all  float_ftd_pct_2021  float_ftd_pct_ytd  \
# ...

# %%
## Sort Highest fails year-to-date
dataframe.sort_values('os_ftd_pct_ytd',ascending=False).head()
# Out:
#       total_ftds_all  total_ftds_2021  total_ftds_ytd  total_ftds_month  \
# SPCB      11516278.0        5794201.0       4185627.0          289659.0
# LABD     107708132.0       18513991.0      18176201.0         1191758.0
# XRT      365970061.0       55298947.0      52243262.0         4104269.0
# UJB        1152446.0         689579.0        622710.0           67831.0
# SRTY      57194845.0       17910592.0      17007924.0          463826.0
#
#       os_ftd_pct_all  os_ftd_pct_2021  os_ftd_pct_ytd  os_ftd_pct_month  \
# SPCB    57240.807197     28799.647100    20804.349123       1439.728615
# LABD     6940.386261      1192.985584     1171.219418         76.793281
# XRT      5223.339003       789.258952      745.646426         58.578530
# UJB      1131.746359       677.193138      611.525204         66.612655
# SRTY     1557.179503       487.631477      463.055554         12.628067
#
#       float_ftd_pct_all  float_ftd_pct_2021  float_ftd_pct_ytd  \
# ...

# %%
## Sort Highest fails past month (January)
dataframe.sort_values('os_ftd_pct_month',ascending=False).head()
# Out:
#       total_ftds_all  total_ftds_2021  total_ftds_ytd  total_ftds_month  \
# SPCB      11516278.0        5794201.0       4185627.0          289659.0
# UNL        4211163.0        2328869.0       2303889.0         1972034.0
# EFZ       19371637.0        4252781.0       4246632.0         2407456.0
# LABD     107708132.0       18513991.0      18176201.0         1191758.0
# CHII       3015345.0        2890692.0       2861693.0         1474297.0
#
#       os_ftd_pct_all  os_ftd_pct_2021  os_ftd_pct_ytd  os_ftd_pct_month  \
# SPCB    57240.807197     28799.647100    20804.349123       1439.728615
# UNL       235.948444       130.484861      129.085249        110.491651
# EFZ       769.004741       168.824594      168.580494         95.569883
# LABD     6940.386261      1192.985584     1171.219418         76.793281
# CHII      156.094199       149.641335      148.140155         76.319363
#
#       float_ftd_pct_all  float_ftd_pct_2021  float_ftd_pct_ytd  \
# ...
