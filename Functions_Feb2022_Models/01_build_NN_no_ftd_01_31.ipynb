# %%
## This file is going to run models which will attempt to forecast price movement 
## using data from 2016 until Jan 31st, 2022. The first 1, 2, 5, and 10 trading days 
## of Februrary will be predicted.

# %%
import pandas as pd

import glob

from pathlib import Path
import csv

import glob

# %%
# Machine-learning specific imports
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import model_from_json

import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler

# %matplotlib inline

# %%
## Load pickle for exports and imports of data  
import pickle 
def load_obj(path):
    with open(path, 'rb') as f:
        return pickle.load(f)
    
def save_obj(obj, path ):
    with open(path, 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

# %%
import datetime

def get_data_updated(symbol,n_days):
    import_path = Path('../FilesExport_Updated_DFs_01_31/'+symbol+'_ti_df_no_ftd.pkl')
    data = load_obj(import_path)
    import_df = data[symbol]
    
    #df - import_df.copy()

    df_close = import_df[['close']]
    df_close = df_close.reset_index().rename(columns={"Date": "Close_Date"})    
    
    features_df = import_df.reset_index().drop(columns=['close','adjClose'])
    
    new_close_df = df_close.iloc[n_days: , :].reset_index(drop=True)
    
    last_date = new_close_df.iloc[-1]['Close_Date']
    last_price = new_close_df.iloc[-1]['close']

    for i in range(n_days):
        if i == 0:
            next_date = last_date + datetime.timedelta(days=1)
            if next_date.weekday() == 5:
                next_date = next_date + datetime.timedelta(days=2)
            d = {'Close_Date': [last_date], 'close': [last_price]}
            df1 = pd.DataFrame(data=d)
            

        else:
            next_date = next_date + datetime.timedelta(days=1)

            if next_date.weekday() == 5:
                next_date = next_date + datetime.timedelta(days=2)

            d2 = {'Close_Date': [next_date], 'close': [last_price]}
            df2 = pd.DataFrame(data=d2)

        ## Append to df1
            df1 = df1.append(df2,ignore_index=True)

    new_close_df = new_close_df.append(df1,ignore_index=True)
    
    return features_df, new_close_df

## Prepare Data for ML
def prepare_data_updated(symbol,n_days,return_data=False):
    features_df, new_close_df = get_data_updated(symbol,n_days)
    
    X = features_df.drop(columns={'Date'}).values
    y = new_close_df['close'].values
    
    scaler = StandardScaler().fit(X)
    X = scaler.transform(X)
    
    if return_data == True:
        return X, y, features_df, new_close_df
    else:
        return X, y

# %%
## Takes one symbol and runs model data. 
## Call function for each individal symbol. No return data.  

def mean_squared_model(
    symbol,
    export_path,  ## Require export path to help avoiding re-writing models 
    n_days = 5, ## Default value 5, but should be tried with 1-30  
    model_count = 5, ## Number of times model runs before saving the best one. 
    validation_split_value=0.3, ## Default 0.3 for 70/30 split 
    epochs_value=400,
    units1 = 8,
    units2 = 8,
    num_of_inputs = 20,
    num_of_outputs= 1,
    model_type = 'NN'
    ):    

    X, y = prepare_data_updated(symbol,n_days)
    
    
    
    n_days_string = str(n_days) ## For exporting because can't concat 'int'
    accuracy_dict_symbol = str(symbol)+'_'+n_days_string
    export_path_prefix_lowAcc = export_path+'Low_Acc/'+symbol+'_'+model_type+'_'+n_days_string 
    export_path_prefix_highAcc = export_path+'High_Acc/'+symbol+'_'+model_type+'_'+n_days_string 


    for i in range(model_count):
        model_summary = {}
        ## Create Neural Network 

        # Define the model - deep neural network with two layers
        nn = Sequential()

        # First hidden layer
        nn.add(Dense(units=units1, input_dim=num_of_inputs, activation="relu"))

        # Second hidden layer
        nn.add(Dense(units=units2, activation="relu"))

        # Output layer
        nn.add(Dense(units=num_of_outputs, activation="linear"))

        # Compile the model
        nn.compile(loss="mean_squared_error", optimizer="adam", metrics=["mse"])

        # Fit the model
        model = nn.fit(X, y, 
                          validation_split=validation_split_value, 
                          epochs=epochs_value, 
                          verbose=0)
            
        ## End of if/elif

        model_loss, model_accuracy = nn.evaluate(X, y, verbose=0)
        
        model_summary = {
            'model_accuracy':model_accuracy,
            'n_days':n_days,
            'validation_split_value':validation_split_value,
            'epochs_value':epochs_value,
                        }
        
        ## Save first model 
        if i == 0:
            model_accuracy_high = model_accuracy
            model_accuracy_low = model_accuracy
            
            symbol_accuracy_dict[accuracy_dict_symbol] = {
                'model_accuracy':model_accuracy,
                'n_days':n_days
            }
            
            # Save model data Low_Acc
            nn_json = nn.to_json()
            file_path = Path(export_path_prefix_lowAcc+'_model_data.json')
            with open(file_path, "w") as json_file:
                json_file.write(nn_json)

            # Save weights
            file_path = (export_path_prefix_lowAcc+'_model_weights.h5')
            nn.save_weights(file_path)
            
            ## Save model summary 
            file_path = (export_path_prefix_lowAcc+'_model_summary.pkl')
            save_obj(model_summary,file_path)
            
            # Save model data High_Acc
            nn_json = nn.to_json()
            file_path = Path(export_path_prefix_highAcc+'_model_data.json')
            with open(file_path, "w") as json_file:
                json_file.write(nn_json)

            # Save weights
            file_path = (export_path_prefix_highAcc+'_model_weights.h5')
            nn.save_weights(file_path)
            
            ## Save model summary 
            file_path = (export_path_prefix_highAcc+'_model_summary.pkl')
            save_obj(model_summary,file_path)
            
        ## Rewrite saved model if accuracy better 
        else:
            if model_accuracy < model_accuracy_low:
                ## Rewrite values 
                model_accuracy_low = model_accuracy
                symbol_accuracy_dict[accuracy_dict_symbol] = {
                    'model_accuracy':model_accuracy,
                    'n_days':n_days
                }
                
                # Rewrite saved files
                
                ## Save model data
                nn_json = nn.to_json()
                file_path = Path(export_path_prefix_lowAcc+'_model_data.json')
                with open(file_path, "w") as json_file:
                    json_file.write(nn_json)

                # Save weights
                file_path = (export_path_prefix_lowAcc+'_model_weights.h5')
                nn.save_weights(file_path)
                
                ## Save model summary 
                file_path = (export_path_prefix_lowAcc+'_model_summary.pkl')
                save_obj(model_summary,file_path)
                
            if model_accuracy > model_accuracy_high:
                ## Rewrite values 
                model_accuracy_high = model_accuracy
                symbol_accuracy_dict[accuracy_dict_symbol] = {
                    'model_accuracy':model_accuracy,
                    'n_days':n_days
                }
                
                # Rewrite saved files
                
                ## Save model data
                nn_json = nn.to_json()
                file_path = Path(export_path_prefix_highAcc+'_model_data.json')
                with open(file_path, "w") as json_file:
                    json_file.write(nn_json)

                # Save weights
                file_path = (export_path_prefix_highAcc+'_model_weights.h5')
                nn.save_weights(file_path)
                
                ## Save model summary 
                file_path = (export_path_prefix_highAcc+'_model_summary.pkl')
                save_obj(model_summary,file_path)
    ## End of for loop 
    ## Return nothing

# %%
## Import symbol list 
path = Path('../Resources/Updated_01_DF_success_list_01_31.pkl')
symbol_list = load_obj(path)
len(symbol_list)
# Out:
# 767

# %%
## Create empty dict for accuracy data - only really needed when 
## looping multiple symbols or different models. 
symbol_accuracy_dict = {}
error_dict = {}
error_count = 0

for index in range(0,len(symbol_list)):
    symbol = symbol_list[index] 
    
    try:
        i = 1
        mean_squared_model(symbol,
                           export_path='../Model_Data/Feb2022_NN_models/',
                           n_days=i,
                           epochs_value=200,
                           validation_split_value=0.1,
                           num_of_inputs=19
                          )
        i = 2
        mean_squared_model(symbol,
                           export_path='../Model_Data/Feb2022_NN_models/',
                           n_days=i,
                           epochs_value=200,
                           validation_split_value=0.1,
                           num_of_inputs=19
                          )
        i = 5
        mean_squared_model(symbol,
                           export_path='../Model_Data/Feb2022_NN_models/',
                           n_days=i,
                           epochs_value=200,
                           validation_split_value=0.1,
                           num_of_inputs=19
                          )
        i = 10
        mean_squared_model(symbol,
                           export_path='../Model_Data/Feb2022_NN_models/',
                           n_days=i,
                           epochs_value=200,
                           validation_split_value=0.1,
                           num_of_inputs=19
                          )
    except:
        error_dict[error_count] = {
            'index':index,
            'symbol':symbol,
            'i':i
        }
        error_count += 1
        continue

## Export symbol_accuracy_dict
path = Path('../Resources/Feb2022_symbol_accuracy_dict.pkl')
save_obj(symbol_accuracy_dict,path)

# %%
symbol_accuracy_dict
# Out:
# {'AAL_1': {'model_accuracy': 1.00552499294281, 'n_days': 1},
#  'AAL_2': {'model_accuracy': 1.990746021270752, 'n_days': 2},
#  'AAL_5': {'model_accuracy': 3.8584377765655518, 'n_days': 5},
#  'AAL_10': {'model_accuracy': 7.194328308105469, 'n_days': 10},
#  'AAU_1': {'model_accuracy': 0.001575897797010839, 'n_days': 1},
#  'AAU_2': {'model_accuracy': 0.0029736601281911135, 'n_days': 2},
#  'AAU_5': {'model_accuracy': 0.006354318931698799, 'n_days': 5},
#  'AAU_10': {'model_accuracy': 0.010364985093474388, 'n_days': 10},
#  'AAXJ_1': {'model_accuracy': 1.2384130954742432, 'n_days': 1},
#  'AAXJ_2': {'model_accuracy': 1.6987038850784302, 'n_days': 2},
#  'AAXJ_5': {'model_accuracy': 3.548926591873169, 'n_days': 5},
#  'AAXJ_10': {'model_accuracy': 6.953153133392334, 'n_days': 10},
#  'ABEO_1': {'model_accuracy': 0.17640310525894165, 'n_days': 1},
#  'ABEO_2': {'model_accuracy': 0.37196213006973267, 'n_days': 2},
#  'ABEO_5': {'model_accuracy': 0.7272997498512268, 'n_days': 5},
#  'ABEO_10': {'model_accuracy': 1.0951393842697144, 'n_days': 10},
#  'ABUS_1': {'model_accuracy': 0.06818191707134247, 'n_days': 1},
#  'ABUS_2': {'model_accuracy': 0.11323077976703644, 'n_days': 2},
#  'ABUS_5': {'model_accuracy': 0.23268991708755493, 'n_days': 5},
#  'ABUS_10': {'model_accuracy': 0.4568158984184265, 'n_days': 10},
#  'ACB_1': {'model_accuracy': 8.227934837341309, 'n_days': 1},
#  'ACB_2': {'model_accuracy': 16.652463912963867, 'n_days': 2},
#  'ACB_5': {'model_accuracy': 45.07404327392578, 'n_days': 5},
#  'ACB_10': {'model_accuracy': 61.115238189697266, 'n_days': 10},
#  'ACER_1': {'model_accuracy': 1.1787800788879395, 'n_days': 1},
#  'ACER_2': {'model_accuracy': 2.183922529220581, 'n_days': 2},
#  'ACER_5': {'model_accuracy': 4.741641044616699, 'n_days': 5},
#  'ACER_10': {'model_accuracy': 9.776543617248535, 'n_days': 10},
#  'ACOR_1': {'model_accuracy': 21.606483459472656, 'n_days': 1},
#  'ACOR_2': {'model_accuracy': 33.95132064819336, 'n_days': 2},
#  'ACOR_5': {'model_accuracy': 79.2068099975586, 'n_days': 5},
#  'ACOR_10': {'model_accuracy': 128.03472900390625, 'n_days': 10},
#  'ACRS_1': {'model_accuracy': 0.568321168422699, 'n_days': 1},
#  'ACRS_2': {'model_accuracy': 0.7850753664970398, 'n_days': 2},
#  'ACRS_5': {'model_accuracy': 1.8469150066375732, 'n_days': 5},
#  'ACRS_10': {'model_accuracy': 2.965245246887207, 'n_days': 10},
#  'ACWI_1': {'model_accuracy': 1.722121000289917, 'n_days': 1},
#  'ACWI_2': {'model_accuracy': 5.75649881362915, 'n_days': 2},
#  'ACWI_5': {'model_accuracy': 14.092495918273926, 'n_days': 5},
#  'ACWI_10': {'model_accuracy': 6.023374557495117, 'n_days': 10},
#  'ACWX_1': {'model_accuracy': 0.8848640322685242, 'n_days': 1},
#  'ACWX_2': {'model_accuracy': 0.5850895047187805, 'n_days': 2},
#  'ACWX_5': {'model_accuracy': 1.1520863771438599, 'n_days': 5},
#  'ACWX_10': {'model_accuracy': 2.215085029602051, 'n_days': 10},
#  'ADMA_1': {'model_accuracy': 0.03875903785228729, 'n_days': 1},
#  'ADMA_2': {'model_accuracy': 0.06178942695260048, 'n_days': 2},
#  'ADMA_5': {'model_accuracy': 0.15651105344295502, 'n_days': 5},
#  'ADMA_10': {'model_accuracy': 0.2635491192340851, 'n_days': 10},
#  'ADMP_1': {'model_accuracy': 0.03770828992128372, 'n_days': 1},
#  'ADMP_2': {'model_accuracy': 0.04500629007816315, 'n_days': 2},
#  'ADMP_5': {'model_accuracy': 0.1187615692615509, 'n_days': 5},
#  'ADMP_10': {'model_accuracy': 0.14943094551563263, 'n_days': 10},
#  'ADVM_1': {'model_accuracy': 0.38171979784965515, 'n_days': 1},
#  'ADVM_2': {'model_accuracy': 0.5935720801353455, 'n_days': 2},
#  'ADVM_5': {'model_accuracy': 1.0757646560668945, 'n_days': 5},
#  'ADVM_10': {'model_accuracy': 1.634678840637207, 'n_days': 10},
#  'AEHL_1': {'model_accuracy': 0.038047317415475845, 'n_days': 1},
#  'AEHL_2': {'model_accuracy': 0.058620914816856384, 'n_days': 2},
#  'AEHL_5': {'model_accuracy': 0.0844266414642334, 'n_days': 5},
#  'AEHL_10': {'model_accuracy': 0.11898284405469894, 'n_days': 10},
#  'AEHR_1': {'model_accuracy': 0.2109740823507309, 'n_days': 1},
#  'AEHR_2': {'model_accuracy': 0.3491269648075104, 'n_days': 2},
#  'AEHR_5': {'model_accuracy': 0.9863632321357727, 'n_days': 5},
#  'AEHR_10': {'model_accuracy': 2.72115421295166, 'n_days': 10},
#  'AEO_1': {'model_accuracy': 0.3035520911216736, 'n_days': 1},
#  'AEO_2': {'model_accuracy': 0.5744854211807251, 'n_days': 2},
#  'AEO_5': {'model_accuracy': 1.2383729219436646, 'n_days': 5},
#  'AEO_10': {'model_accuracy': 2.357059955596924, 'n_days': 10},
#  'AEZS_1': {'model_accuracy': 0.016133593395352364, 'n_days': 1},
#  'AEZS_2': {'model_accuracy': 0.03045741841197014, 'n_days': 2},
#  'AEZS_5': {'model_accuracy': 0.06637224555015564, 'n_days': 5},
#  'AEZS_10': {'model_accuracy': 0.12109994888305664, 'n_days': 10},
#  'AG_1': {'model_accuracy': 0.15892906486988068, 'n_days': 1},
#  'AG_2': {'model_accuracy': 0.2999083995819092, 'n_days': 2},
#  'AG_5': {'model_accuracy': 0.648860514163971, 'n_days': 5},
#  'AG_10': {'model_accuracy': 1.1696386337280273, 'n_days': 10},
#  'AGQ_1': {'model_accuracy': 1.7398749589920044, 'n_days': 1},
#  'AGQ_2': {'model_accuracy': 3.143704652786255, 'n_days': 2},
#  'AGQ_5': {'model_accuracy': 8.041421890258789, 'n_days': 5},
#  'AGQ_10': {'model_accuracy': 12.680060386657715, 'n_days': 10},
#  'AHPI_1': {'model_accuracy': 11.16524600982666, 'n_days': 1},
#  'AHPI_2': {'model_accuracy': 14.178112030029297, 'n_days': 2},
#  'AHPI_5': {'model_accuracy': 106.07193756103516, 'n_days': 5},
#  'AHPI_10': {'model_accuracy': 19.601228713989258, 'n_days': 10},
#  'AIA_1': {'model_accuracy': 1.6971279382705688, 'n_days': 1},
#  'AIA_2': {'model_accuracy': 9.04918098449707, 'n_days': 2},
#  'AIA_5': {'model_accuracy': 5.772789001464844, 'n_days': 5},
#  'AIA_10': {'model_accuracy': 8.214612007141113, 'n_days': 10},
#  'AIKI_1': {'model_accuracy': 0.0940060019493103, 'n_days': 1},
#  'AIKI_2': {'model_accuracy': 0.17437106370925903, 'n_days': 2},
#  'AIKI_5': {'model_accuracy': 0.29378607869148254, 'n_days': 5},
#  'AIKI_10': {'model_accuracy': 0.48551860451698303, 'n_days': 10},
#  'AIRI_1': {'model_accuracy': 0.009758870117366314, 'n_days': 1},
#  'AIRI_2': {'model_accuracy': 0.016230283305048943, 'n_days': 2},
#  'AIRI_5': {'model_accuracy': 0.03676000237464905, 'n_days': 5},
#  'AIRI_10': {'model_accuracy': 0.06056687980890274, 'n_days': 10},
#  'ALJJ_1': {'model_accuracy': 0.006828646641224623, 'n_days': 1},
#  'ALJJ_2': {'model_accuracy': 0.012634191662073135, 'n_days': 2},
#  'ALJJ_5': {'model_accuracy': 0.028258726000785828, 'n_days': 5},
#  'ALJJ_10': {'model_accuracy': 0.03949187695980072, 'n_days': 10},
#  'ALTO_1': {'model_accuracy': 0.04503372684121132, 'n_days': 1},
#  'ALTO_2': {'model_accuracy': 0.09740659594535828, 'n_days': 2},
#  'ALTO_5': {'model_accuracy': 0.1816428303718567, 'n_days': 5},
#  'ALTO_10': {'model_accuracy': 0.36543092131614685, 'n_days': 10},
#  'AMC_1': {'model_accuracy': 3.2739408016204834, 'n_days': 1},
#  'AMC_2': {'model_accuracy': 3.757314443588257, 'n_days': 2},
#  'AMC_5': {'model_accuracy': 6.112754821777344, 'n_days': 5},
#  'AMC_10': {'model_accuracy': 17.52499008178711, 'n_days': 10},
#  'AMCX_1': {'model_accuracy': 1.7686305046081543, 'n_days': 1},
#  'AMCX_2': {'model_accuracy': 4.117579460144043, 'n_days': 2},
#  'AMCX_5': {'model_accuracy': 7.59292459487915, 'n_days': 5},
#  'AMCX_10': {'model_accuracy': 14.799186706542969, 'n_days': 10},
#  'AMPE_1': {'model_accuracy': 0.01232971902936697, 'n_days': 1},
#  'AMPE_2': {'model_accuracy': 0.02566528134047985, 'n_days': 2},
#  'AMPE_5': {'model_accuracy': 0.045980412513017654, 'n_days': 5},
#  'AMPE_10': {'model_accuracy': 0.09060166776180267, 'n_days': 10},
#  'AMS_1': {'model_accuracy': 0.012681637890636921, 'n_days': 1},
#  'AMS_2': {'model_accuracy': 0.018643518909811974, 'n_days': 2},
#  'AMS_5': {'model_accuracy': 0.03723878040909767, 'n_days': 5},
#  'AMS_10': {'model_accuracy': 0.058363571763038635, 'n_days': 10},
#  'AMSC_1': {'model_accuracy': 0.24205678701400757, 'n_days': 1},
#  'AMSC_2': {'model_accuracy': 0.47448402643203735, 'n_days': 2},
#  'AMSC_5': {'model_accuracy': 1.1593588590621948, 'n_days': 5},
#  'AMSC_10': {'model_accuracy': 1.783768653869629, 'n_days': 10},
#  'AMTX_1': {'model_accuracy': 0.2073608785867691, 'n_days': 1},
#  'AMTX_2': {'model_accuracy': 0.3689369857311249, 'n_days': 2},
#  'AMTX_5': {'model_accuracy': 0.9260002374649048, 'n_days': 5},
#  'AMTX_10': {'model_accuracy': 1.2426577806472778, 'n_days': 10},
#  'ANIX_1': {'model_accuracy': 0.03782271966338158, 'n_days': 1},
#  'ANIX_2': {'model_accuracy': 0.07236199826002121, 'n_days': 2},
#  'ANIX_5': {'model_accuracy': 0.17172928154468536, 'n_days': 5},
#  'ANIX_10': {'model_accuracy': 0.2746865749359131, 'n_days': 10},
#  'ANTE_1': {'model_accuracy': 0.08075328171253204, 'n_days': 1},
#  'ANTE_2': {'model_accuracy': 0.17132721841335297, 'n_days': 2},
#  'ANTE_5': {'model_accuracy': 0.4269263446331024, 'n_days': 5},
#  'ANTE_10': {'model_accuracy': 0.7582921385765076, 'n_days': 10},
#  'ANY_1': {'model_accuracy': 20.264999389648438, 'n_days': 1},
#  'ANY_2': {'model_accuracy': 37.39862060546875, 'n_days': 2},
#  'ANY_5': {'model_accuracy': 56.755638122558594, 'n_days': 5},
#  'ANY_10': {'model_accuracy': 82.92338562011719, 'n_days': 10},
#  'APT_1': {'model_accuracy': 0.28079867362976074, 'n_days': 1},
#  'APT_2': {'model_accuracy': 0.42274990677833557, 'n_days': 2},
#  'APT_5': {'model_accuracy': 1.211958408355713, 'n_days': 5},
#  'APT_10': {'model_accuracy': 1.2614891529083252, 'n_days': 10},
#  'AQMS_1': {'model_accuracy': 0.11546243727207184, 'n_days': 1},
#  'AQMS_2': {'model_accuracy': 0.202205091714859, 'n_days': 2},
#  'AQMS_5': {'model_accuracy': 0.5529776811599731, 'n_days': 5},
#  'AQMS_10': {'model_accuracy': 0.9965001940727234, 'n_days': 10},
#  'ARAV_1': {'model_accuracy': 10.010749816894531, 'n_days': 1},
#  'ARAV_2': {'model_accuracy': 18.693071365356445, 'n_days': 2},
#  'ARAV_5': {'model_accuracy': 35.487735748291016, 'n_days': 5},
#  'ARAV_10': {'model_accuracy': 66.25190734863281, 'n_days': 10},
#  'ARCT_1': {'model_accuracy': 7.965694904327393, 'n_days': 1},
#  'ARCT_2': {'model_accuracy': 13.524680137634277, 'n_days': 2},
#  'ARCT_5': {'model_accuracy': 26.48783302307129, 'n_days': 5},
#  'ARCT_10': {'model_accuracy': 38.89267349243164, 'n_days': 10},
#  'ARDX_1': {'model_accuracy': 0.2277742326259613, 'n_days': 1},
#  'ARDX_2': {'model_accuracy': 3.853675365447998, 'n_days': 2},
#  'ARDX_5': {'model_accuracy': 6.758674621582031, 'n_days': 5},
#  'ARDX_10': {'model_accuracy': 1.4086992740631104, 'n_days': 10},
#  'ARGT_1': {'model_accuracy': 0.2648093104362488, 'n_days': 1},
#  'ARGT_2': {'model_accuracy': 0.607340931892395, 'n_days': 2},
#  'ARGT_5': {'model_accuracy': 1.2478374242782593, 'n_days': 5},
#  'ARGT_10': {'model_accuracy': 2.405937910079956, 'n_days': 10},
#  'ARR_1': {'model_accuracy': 0.08301027119159698, 'n_days': 1},
#  'ARR_2': {'model_accuracy': 0.17821438610553741, 'n_days': 2},
#  'ARR_5': {'model_accuracy': 0.4168072044849396, 'n_days': 5},
#  'ARR_10': {'model_accuracy': 0.9013363122940063, 'n_days': 10},
#  'ASHR_1': {'model_accuracy': 0.957619309425354, 'n_days': 1},
#  'ASHR_2': {'model_accuracy': 0.6466829776763916, 'n_days': 2},
#  'ASHR_5': {'model_accuracy': 0.9320050477981567, 'n_days': 5},
#  'ASHR_10': {'model_accuracy': 1.606850028038025, 'n_days': 10},
#  'ASM_1': {'model_accuracy': 0.002980154240503907, 'n_days': 1},
#  'ASM_2': {'model_accuracy': 0.005164643283933401, 'n_days': 2},
#  'ASM_5': {'model_accuracy': 0.011395204812288284, 'n_days': 5},
#  'ASM_10': {'model_accuracy': 0.022076541557908058, 'n_days': 10},
#  'ASTC_1': {'model_accuracy': 0.09954259544610977, 'n_days': 1},
#  'ASTC_2': {'model_accuracy': 0.1356927901506424, 'n_days': 2},
#  'ASTC_5': {'model_accuracy': 0.23665152490139008, 'n_days': 5},
#  'ASTC_10': {'model_accuracy': 0.34149205684661865, 'n_days': 10},
#  'ASXC_1': {'model_accuracy': 3.3430209159851074, 'n_days': 1},
#  'ASXC_2': {'model_accuracy': 6.102810382843018, 'n_days': 2},
#  'ASXC_5': {'model_accuracy': 16.027639389038086, 'n_days': 5},
#  'ASXC_10': {'model_accuracy': 26.642187118530273, 'n_days': 10},
#  'ATHE_1': {'model_accuracy': 0.018483852967619896, 'n_days': 1},
#  'ATHE_2': {'model_accuracy': 0.035243920981884, 'n_days': 2},
#  'ATHE_5': {'model_accuracy': 0.05071936547756195, 'n_days': 5},
#  'ATHE_10': {'model_accuracy': 0.09142214059829712, 'n_days': 10},
#  'ATHX_1': {'model_accuracy': 0.007934226654469967, 'n_days': 1},
#  'ATHX_2': {'model_accuracy': 0.013736540451645851, 'n_days': 2},
#  'ATHX_5': {'model_accuracy': 0.024123920127749443, 'n_days': 5},
#  'ATHX_10': {'model_accuracy': 0.044107746332883835, 'n_days': 10},
#  'ATNM_1': {'model_accuracy': 1.2900705337524414, 'n_days': 1},
#  'ATNM_2': {'model_accuracy': 1.8515278100967407, 'n_days': 2},
#  'ATNM_5': {'model_accuracy': 4.2876691818237305, 'n_days': 5},
#  'ATNM_10': {'model_accuracy': 7.501759052276611, 'n_days': 10},
#  'ATOS_1': {'model_accuracy': 1.3101756572723389, 'n_days': 1},
#  'ATOS_2': {'model_accuracy': 2.3596713542938232, 'n_days': 2},
#  'ATOS_5': {'model_accuracy': 3.9337096214294434, 'n_days': 5},
#  'ATOS_10': {'model_accuracy': 6.721202373504639, 'n_days': 10},
#  'AUMN_1': {'model_accuracy': 0.000739624781999737, 'n_days': 1},
#  'AUMN_2': {'model_accuracy': 0.0014025818090885878, 'n_days': 2},
#  'AUMN_5': {'model_accuracy': 0.0024506044574081898, 'n_days': 5},
#  'AUMN_10': {'model_accuracy': 0.0037152899894863367, 'n_days': 10},
#  'AUPH_1': {'model_accuracy': 0.31048306822776794, 'n_days': 1},
#  'AUPH_2': {'model_accuracy': 0.7069863677024841, 'n_days': 2},
#  'AUPH_5': {'model_accuracy': 1.6073617935180664, 'n_days': 5},
#  'AUPH_10': {'model_accuracy': 2.741612672805786, 'n_days': 10},
#  'AUTO_1': {'model_accuracy': 0.09549915045499802, 'n_days': 1},
#  'AUTO_2': {'model_accuracy': 0.191228985786438, 'n_days': 2},
#  'AUTO_5': {'model_accuracy': 0.32622426748275757, 'n_days': 5},
#  'AUTO_10': {'model_accuracy': 0.5553654432296753, 'n_days': 10},
#  'AVDL_1': {'model_accuracy': 0.08934810012578964, 'n_days': 1},
#  'AVDL_2': {'model_accuracy': 0.32577580213546753, 'n_days': 2},
#  'AVDL_5': {'model_accuracy': 0.4649151563644409, 'n_days': 5},
#  'AVDL_10': {'model_accuracy': 0.9675630331039429, 'n_days': 10},
#  'AXDX_1': {'model_accuracy': 0.4142531752586365, 'n_days': 1},
#  'AXDX_2': {'model_accuracy': 0.6747650504112244, 'n_days': 2},
#  'AXDX_5': {'model_accuracy': 1.7119238376617432, 'n_days': 5},
#  'AXDX_10': {'model_accuracy': 3.525130271911621, 'n_days': 10},
#  'AYRO_1': {'model_accuracy': 27.07002067565918, 'n_days': 1},
#  'AYRO_2': {'model_accuracy': 40.80240249633789, 'n_days': 2},
#  'AYRO_5': {'model_accuracy': 79.70790100097656, 'n_days': 5},
#  'AYRO_10': {'model_accuracy': 129.94601440429688, 'n_days': 10},
#  'AYTU_1': {'model_accuracy': 237177.015625, 'n_days': 1},
#  'AYTU_2': {'model_accuracy': 583226.8125, 'n_days': 2},
#  'AYTU_5': {'model_accuracy': 566721.25, 'n_days': 5},
#  'AYTU_10': {'model_accuracy': 1031948.6875, 'n_days': 10},
#  'BB_1': {'model_accuracy': 0.09473878890275955, 'n_days': 1},
#  'BB_2': {'model_accuracy': 0.161477729678154, 'n_days': 2},
#  'BB_5': {'model_accuracy': 0.4760814309120178, 'n_days': 5},
#  'BB_10': {'model_accuracy': 1.2398591041564941, 'n_days': 10},
#  'BBBY_1': {'model_accuracy': 1.0576468706130981, 'n_days': 1},
#  'BBBY_2': {'model_accuracy': 1.7306691408157349, 'n_days': 2},
#  'BBBY_5': {'model_accuracy': 3.772073268890381, 'n_days': 5},
#  'BBBY_10': {'model_accuracy': 5.910079479217529, 'n_days': 10},
#  'BBI_1': {'model_accuracy': 0.20552898943424225, 'n_days': 1},
#  'BBI_2': {'model_accuracy': 0.32879820466041565, 'n_days': 2},
#  'BBI_5': {'model_accuracy': 0.6370437741279602, 'n_days': 5},
#  'BBI_10': {'model_accuracy': 0.880387008190155, 'n_days': 10},
#  'BCLI_1': {'model_accuracy': 0.09416093677282333, 'n_days': 1},
#  'BCLI_2': {'model_accuracy': 0.16005688905715942, 'n_days': 2},
#  'BCLI_5': {'model_accuracy': 0.31139951944351196, 'n_days': 5},
#  'BCLI_10': {'model_accuracy': 0.6697956323623657, 'n_days': 10},
#  'BCRX_1': {'model_accuracy': 0.138296440243721, 'n_days': 1},
#  'BCRX_2': {'model_accuracy': 0.23665395379066467, 'n_days': 2},
#  'BCRX_5': {'model_accuracy': 0.4816456139087677, 'n_days': 5},
#  'BCRX_10': {'model_accuracy': 0.8887065649032593, 'n_days': 10},
#  'BEEM_1': {'model_accuracy': 1.9023504257202148, 'n_days': 1},
#  'BEEM_2': {'model_accuracy': 2.743633270263672, 'n_days': 2},
#  'BEEM_5': {'model_accuracy': 6.274212837219238, 'n_days': 5},
#  'BEEM_10': {'model_accuracy': 9.498726844787598, 'n_days': 10},
#  'BGFV_1': {'model_accuracy': 0.5137953162193298, 'n_days': 1},
#  'BGFV_2': {'model_accuracy': 1.0545556545257568, 'n_days': 2},
#  'BGFV_5': {'model_accuracy': 2.56166672706604, 'n_days': 5},
#  'BGFV_10': {'model_accuracy': 4.575259685516357, 'n_days': 10},
#  'BGS_1': {'model_accuracy': 0.5447354316711426, 'n_days': 1},
#  'BGS_2': {'model_accuracy': 1.1106514930725098, 'n_days': 2},
#  'BGS_5': {'model_accuracy': 2.476808547973633, 'n_days': 5},
#  'BGS_10': {'model_accuracy': 4.24602746963501, 'n_days': 10},
#  'BIB_1': {'model_accuracy': 4.034036159515381, 'n_days': 1},
#  'BIB_2': {'model_accuracy': 6.181624412536621, 'n_days': 2},
#  'BIB_5': {'model_accuracy': 15.31452751159668, 'n_days': 5},
#  'BIB_10': {'model_accuracy': 27.54319953918457, 'n_days': 10},
#  'BIMI_1': {'model_accuracy': 0.8811905980110168, 'n_days': 1},
#  'BIMI_2': {'model_accuracy': 0.34834024310112, 'n_days': 2},
#  'BIMI_5': {'model_accuracy': 0.6413648724555969, 'n_days': 5},
#  'BIMI_10': {'model_accuracy': 0.9888167381286621, 'n_days': 10},
#  'BIS_1': {'model_accuracy': 8.37365436553955, 'n_days': 1},
#  'BIS_2': {'model_accuracy': 14.169721603393555, 'n_days': 2},
#  'BIS_5': {'model_accuracy': 31.87042236328125, 'n_days': 5},
#  'BIS_10': {'model_accuracy': 56.863243103027344, 'n_days': 10},
#  'BKYI_1': {'model_accuracy': 1.330032467842102, 'n_days': 1},
#  'BKYI_2': {'model_accuracy': 1.5750919580459595, 'n_days': 2},
#  'BKYI_5': {'model_accuracy': 2.3194525241851807, 'n_days': 5},
#  'BKYI_10': {'model_accuracy': 3.382460117340088, 'n_days': 10},
#  'BLDP_1': {'model_accuracy': 0.3162217438220978, 'n_days': 1},
#  'BLDP_2': {'model_accuracy': 0.6213452816009521, 'n_days': 2},
#  'BLDP_5': {'model_accuracy': 1.2950005531311035, 'n_days': 5},
#  'BLDP_10': {'model_accuracy': 2.706310749053955, 'n_days': 10},
#  'BLIN_1': {'model_accuracy': 37.302589416503906, 'n_days': 1},
#  'BLIN_2': {'model_accuracy': 67.13153076171875, 'n_days': 2},
#  'BLIN_5': {'model_accuracy': 122.24310302734375, 'n_days': 5},
#  'BLIN_10': {'model_accuracy': 196.11114501953125, 'n_days': 10},
#  'BLNK_1': {'model_accuracy': 1.8023242950439453, 'n_days': 1},
#  'BLNK_2': {'model_accuracy': 3.165269374847412, 'n_days': 2},
#  'BLNK_5': {'model_accuracy': 7.941544055938721, 'n_days': 5},
#  'BLNK_10': {'model_accuracy': 11.957633018493652, 'n_days': 10},
#  'BLPH_1': {'model_accuracy': 1.6446983814239502, 'n_days': 1},
#  'BLPH_2': {'model_accuracy': 3.3984313011169434, 'n_days': 2},
#  'BLPH_5': {'model_accuracy': 6.069121837615967, 'n_days': 5},
#  'BLPH_10': {'model_accuracy': 12.200413703918457, 'n_days': 10},
#  'BLV_1': {'model_accuracy': 1.767543077468872, 'n_days': 1},
#  'BLV_2': {'model_accuracy': 2.5971291065216064, 'n_days': 2},
#  'BLV_5': {'model_accuracy': 2.241631031036377, 'n_days': 5},
#  'BLV_10': {'model_accuracy': 11.609501838684082, 'n_days': 10},
#  'BNFT_1': {'model_accuracy': 0.707689106464386, 'n_days': 1},
#  'BNFT_2': {'model_accuracy': 1.4786795377731323, 'n_days': 2},
#  'BNFT_5': {'model_accuracy': 3.7080841064453125, 'n_days': 5},
#  'BNFT_10': {'model_accuracy': 6.471127033233643, 'n_days': 10},
#  'BNO_1': {'model_accuracy': 0.11806905269622803, 'n_days': 1},
#  'BNO_2': {'model_accuracy': 0.22858165204524994, 'n_days': 2},
#  'BNO_5': {'model_accuracy': 0.5527670979499817, 'n_days': 5},
#  'BNO_10': {'model_accuracy': 1.0662071704864502, 'n_days': 10},
#  'BOSC_1': {'model_accuracy': 0.011024109087884426, 'n_days': 1},
#  'BOSC_2': {'model_accuracy': 0.016771886497735977, 'n_days': 2},
#  'BOSC_5': {'model_accuracy': 0.05021711811423302, 'n_days': 5},
#  'BOSC_10': {'model_accuracy': 0.06741231679916382, 'n_days': 10},
#  'BPTH_1': {'model_accuracy': 40.1466178894043, 'n_days': 1},
#  'BPTH_2': {'model_accuracy': 78.54352569580078, 'n_days': 2},
#  'BPTH_5': {'model_accuracy': 212.75938415527344, 'n_days': 5},
#  'BPTH_10': {'model_accuracy': 381.691162109375, 'n_days': 10},
#  'BSGM_1': {'model_accuracy': 0.0869186595082283, 'n_days': 1},
#  'BSGM_2': {'model_accuracy': 0.14477182924747467, 'n_days': 2},
#  'BSGM_5': {'model_accuracy': 0.305115669965744, 'n_days': 5},
#  'BSGM_10': {'model_accuracy': 0.4558684825897217, 'n_days': 10},
#  'BSQR_1': {'model_accuracy': 0.07746431231498718, 'n_days': 1},
#  'BSQR_2': {'model_accuracy': 0.4506237804889679, 'n_days': 2},
#  'BSQR_5': {'model_accuracy': 1.92018723487854, 'n_days': 5},
#  'BSQR_10': {'model_accuracy': 1.8867238759994507, 'n_days': 10},
#  'BST_1': {'model_accuracy': 0.4495515525341034, 'n_days': 1},
#  'BST_2': {'model_accuracy': 0.7601840496063232, 'n_days': 2},
#  'BST_5': {'model_accuracy': 1.7903753519058228, 'n_days': 5},
#  'BST_10': {'model_accuracy': 3.5985138416290283, 'n_days': 10},
#  'BTCM_1': {'model_accuracy': 1.075467586517334, 'n_days': 1},
#  'BTCM_2': {'model_accuracy': 12.337079048156738, 'n_days': 2},
#  'BTCM_5': {'model_accuracy': 1.6017160415649414, 'n_days': 5},
#  'BTCM_10': {'model_accuracy': 8.371368408203125, 'n_days': 10},
#  'BTX_1': {'model_accuracy': 1.1749892234802246, 'n_days': 1},
#  'BTX_2': {'model_accuracy': 2.277538537979126, 'n_days': 2},
#  'BTX_5': {'model_accuracy': 5.593155860900879, 'n_days': 5},
#  'BTX_10': {'model_accuracy': 8.893799781799316, 'n_days': 10},
#  'BWEN_1': {'model_accuracy': 0.0525924451649189, 'n_days': 1},
#  'BWEN_2': {'model_accuracy': 0.07971757650375366, 'n_days': 2},
#  'BWEN_5': {'model_accuracy': 0.16150185465812683, 'n_days': 5},
#  'BWEN_10': {'model_accuracy': 0.2746080756187439, 'n_days': 10},
#  'BWX_1': {'model_accuracy': 0.05042004957795143, 'n_days': 1},
#  'BWX_2': {'model_accuracy': 0.06447937339544296, 'n_days': 2},
#  'BWX_5': {'model_accuracy': 0.12290804833173752, 'n_days': 5},
#  'BWX_10': {'model_accuracy': 0.15321418642997742, 'n_days': 10},
#  'BWZ_1': {'model_accuracy': 0.10687598586082458, 'n_days': 1},
#  'BWZ_2': {'model_accuracy': 0.05121878534555435, 'n_days': 2},
#  'BWZ_5': {'model_accuracy': 0.3693254590034485, 'n_days': 5},
#  'BWZ_10': {'model_accuracy': 0.15678685903549194, 'n_days': 10},
#  'CAAS_1': {'model_accuracy': 0.0482315868139267, 'n_days': 1},
#  'CAAS_2': {'model_accuracy': 0.0778140276670456, 'n_days': 2},
#  'CAAS_5': {'model_accuracy': 0.14498686790466309, 'n_days': 5},
#  'CAAS_10': {'model_accuracy': 0.2897968590259552, 'n_days': 10},
#  'CANE_1': {'model_accuracy': 0.03916515037417412, 'n_days': 1},
#  'CANE_2': {'model_accuracy': 0.03829590603709221, 'n_days': 2},
#  'CANE_5': {'model_accuracy': 0.07623447477817535, 'n_days': 5},
#  'CANE_10': {'model_accuracy': 0.15620096027851105, 'n_days': 10},
#  'CAPR_1': {'model_accuracy': 1.0151597261428833, 'n_days': 1},
#  'CAPR_2': {'model_accuracy': 1.9089206457138062, 'n_days': 2},
#  'CAPR_5': {'model_accuracy': 4.214564323425293, 'n_days': 5},
#  'CAPR_10': {'model_accuracy': 7.023914813995361, 'n_days': 10},
#  'CAR_1': {'model_accuracy': 38.382266998291016, 'n_days': 1},
#  'CAR_2': {'model_accuracy': 76.73493194580078, 'n_days': 2},
#  'CAR_5': {'model_accuracy': 97.61346435546875, 'n_days': 5},
#  'CAR_10': {'model_accuracy': 179.8896942138672, 'n_days': 10},
#  'CASI_1': {'model_accuracy': 0.022698910906910896, 'n_days': 1},
#  'CASI_2': {'model_accuracy': 0.18337394297122955, 'n_days': 2},
#  'CASI_5': {'model_accuracy': 0.24975597858428955, 'n_days': 5},
#  'CASI_10': {'model_accuracy': 0.16443072259426117, 'n_days': 10},
#  'CBAT_1': {'model_accuracy': 0.02757207304239273, 'n_days': 1},
#  'CBAT_2': {'model_accuracy': 0.08314592391252518, 'n_days': 2},
#  'CBAT_5': {'model_accuracy': 0.16987963020801544, 'n_days': 5},
#  'CBAT_10': {'model_accuracy': 0.2909298539161682, 'n_days': 10},
#  'CCXI_1': {'model_accuracy': 3.8853867053985596, 'n_days': 1},
#  'CCXI_2': {'model_accuracy': 5.180669784545898, 'n_days': 2},
#  'CCXI_5': {'model_accuracy': 11.107382774353027, 'n_days': 5},
#  'CCXI_10': {'model_accuracy': 17.51008415222168, 'n_days': 10},
#  'CDC_1': {'model_accuracy': 0.2976846694946289, 'n_days': 1},
#  'CDC_2': {'model_accuracy': 0.49685683846473694, 'n_days': 2},
#  'CDC_5': {'model_accuracy': 2.0579957962036133, 'n_days': 5},
#  'CDC_10': {'model_accuracy': 1.5904197692871094, 'n_days': 10},
#  'CDTX_1': {'model_accuracy': 0.0638965293765068, 'n_days': 1},
#  'CDTX_2': {'model_accuracy': 0.14219039678573608, 'n_days': 2},
#  'CDTX_5': {'model_accuracy': 0.2980141043663025, 'n_days': 5},
#  'CDTX_10': {'model_accuracy': 0.4092998802661896, 'n_days': 10},
#  'CDZI_1': {'model_accuracy': 0.09565719217061996, 'n_days': 1},
#  'CDZI_2': {'model_accuracy': 0.24892732501029968, 'n_days': 2},
#  'CDZI_5': {'model_accuracy': 0.45082759857177734, 'n_days': 5},
#  'CDZI_10': {'model_accuracy': 1.0587962865829468, 'n_days': 10},
#  'CEMI_1': {'model_accuracy': 0.9591076970100403, 'n_days': 1},
#  'CEMI_2': {'model_accuracy': 0.5906153321266174, 'n_days': 2},
#  'CEMI_5': {'model_accuracy': 1.3104535341262817, 'n_days': 5},
#  'CEMI_10': {'model_accuracy': 6.18003511428833, 'n_days': 10},
#  'CETX_1': {'model_accuracy': 1.0441710948944092, 'n_days': 1},
#  'CETX_2': {'model_accuracy': 1.6834977865219116, 'n_days': 2},
#  'CETX_5': {'model_accuracy': 3.7210543155670166, 'n_days': 5},
#  'CETX_10': {'model_accuracy': 6.6440534591674805, 'n_days': 10},
#  'CFMS_1': {'model_accuracy': 0.053798969835042953, 'n_days': 1},
#  'CFMS_2': {'model_accuracy': 0.09756620973348618, 'n_days': 2},
#  'CFMS_5': {'model_accuracy': 0.2365400493144989, 'n_days': 5},
#  'CFMS_10': {'model_accuracy': 0.24793945252895355, 'n_days': 10},
#  'CFO_1': {'model_accuracy': 1.729561448097229, 'n_days': 1},
#  'CFO_2': {'model_accuracy': 2.6305925846099854, 'n_days': 2},
#  'CFO_5': {'model_accuracy': 1.4421666860580444, 'n_days': 5},
#  'CFO_10': {'model_accuracy': 4.678924560546875, 'n_days': 10},
#  'CGA_1': {'model_accuracy': 0.14887025952339172, 'n_days': 1},
#  'CGA_2': {'model_accuracy': 0.29752209782600403, 'n_days': 2},
#  'CGA_5': {'model_accuracy': 0.6072299480438232, 'n_days': 5},
#  'CGA_10': {'model_accuracy': 1.0530352592468262, 'n_days': 10},
#  'CGC_1': {'model_accuracy': 1.2831639051437378, 'n_days': 1},
#  'CGC_2': {'model_accuracy': 2.3746120929718018, 'n_days': 2},
#  'CGC_5': {'model_accuracy': 5.9352192878723145, 'n_days': 5},
#  'CGC_10': {'model_accuracy': 9.679083824157715, 'n_days': 10},
#  'CHAD_1': {'model_accuracy': 0.2571677565574646, 'n_days': 1},
#  'CHAD_2': {'model_accuracy': 0.48333096504211426, 'n_days': 2},
#  'CHAD_5': {'model_accuracy': 0.8412545323371887, 'n_days': 5},
#  'CHAD_10': {'model_accuracy': 1.6346256732940674, 'n_days': 10},
#  'CHAU_1': {'model_accuracy': 0.607775866985321, 'n_days': 1},
#  'CHAU_2': {'model_accuracy': 1.14082932472229, 'n_days': 2},
#  'CHAU_5': {'model_accuracy': 2.8453776836395264, 'n_days': 5},
#  'CHAU_10': {'model_accuracy': 5.243117809295654, 'n_days': 10},
#  'CHEF_1': {'model_accuracy': 0.6346184015274048, 'n_days': 1},
#  'CHEF_2': {'model_accuracy': 1.1480777263641357, 'n_days': 2},
#  'CHEF_5': {'model_accuracy': 2.55891489982605, 'n_days': 5},
#  'CHEF_10': {'model_accuracy': 5.758785247802734, 'n_days': 10},
#  'CHEK_1': {'model_accuracy': 3.7874436378479004, 'n_days': 1},
#  'CHEK_2': {'model_accuracy': 4.676464080810547, 'n_days': 2},
#  'CHEK_5': {'model_accuracy': 4.237439155578613, 'n_days': 5},
#  'CHEK_10': {'model_accuracy': 5.174750804901123, 'n_days': 10},
#  'CIBR_1': {'model_accuracy': 0.22897134721279144, 'n_days': 1},
#  'CIBR_2': {'model_accuracy': 0.4042562246322632, 'n_days': 2},
#  'CIBR_5': {'model_accuracy': 1.053285002708435, 'n_days': 5},
#  'CIBR_10': {'model_accuracy': 2.3819916248321533, 'n_days': 10},
#  'CIDM_1': {'model_accuracy': 0.009612164460122585, 'n_days': 1},
#  'CIDM_2': {'model_accuracy': 0.019672153517603874, 'n_days': 2},
#  'CIDM_5': {'model_accuracy': 0.03538542240858078, 'n_days': 5},
#  'CIDM_10': {'model_accuracy': 0.0471157506108284, 'n_days': 10},
#  'CIVI_1': {'model_accuracy': 112.29981994628906, 'n_days': 1},
#  'CIVI_2': {'model_accuracy': 205.25521850585938, 'n_days': 2},
#  'CIVI_5': {'model_accuracy': 403.8242492675781, 'n_days': 5},
#  'CIVI_10': {'model_accuracy': 719.7796630859375, 'n_days': 10},
#  'CJJD_1': {'model_accuracy': 0.01824391447007656, 'n_days': 1},
#  'CJJD_2': {'model_accuracy': 0.0072477455250918865, 'n_days': 2},
#  'CJJD_5': {'model_accuracy': 0.031103787943720818, 'n_days': 5},
#  'CJJD_10': {'model_accuracy': 0.034691426903009415, 'n_days': 10},
#  'CLM_1': {'model_accuracy': 0.0330878309905529, 'n_days': 1},
#  'CLM_2': {'model_accuracy': 0.06558200716972351, 'n_days': 2},
#  'CLM_5': {'model_accuracy': 0.19385291635990143, 'n_days': 5},
#  'CLM_10': {'model_accuracy': 0.28192564845085144, 'n_days': 10},
#  'CLR_1': {'model_accuracy': 1.5627144575119019, 'n_days': 1},
#  'CLR_2': {'model_accuracy': 2.811190605163574, 'n_days': 2},
#  'CLR_5': {'model_accuracy': 6.108345985412598, 'n_days': 5},
#  'CLR_10': {'model_accuracy': 10.845952987670898, 'n_days': 10},
#  'CLRB_1': {'model_accuracy': 1.1179968118667603, 'n_days': 1},
#  'CLRB_2': {'model_accuracy': 1.9895625114440918, 'n_days': 2},
#  'CLRB_5': {'model_accuracy': 3.840183734893799, 'n_days': 5},
#  'CLRB_10': {'model_accuracy': 4.0153489112854, 'n_days': 10},
#  'CLSN_1': {'model_accuracy': 0.09424188733100891, 'n_days': 1},
#  'CLSN_2': {'model_accuracy': 0.1538831740617752, 'n_days': 2},
#  'CLSN_5': {'model_accuracy': 0.2817766070365906, 'n_days': 5},
#  'CLSN_10': {'model_accuracy': 0.33917954564094543, 'n_days': 10},
#  'CLVS_1': {'model_accuracy': 2.615518569946289, 'n_days': 1},
#  'CLVS_2': {'model_accuracy': 5.520674705505371, 'n_days': 2},
#  'CLVS_5': {'model_accuracy': 12.005477905273438, 'n_days': 5},
#  'CLVS_10': {'model_accuracy': 20.77958106994629, 'n_days': 10},
#  'CMBS_1': {'model_accuracy': 0.21655169129371643, 'n_days': 1},
#  'CMBS_2': {'model_accuracy': 1.0105791091918945, 'n_days': 2},
#  'CMBS_5': {'model_accuracy': 0.2029733508825302, 'n_days': 5},
#  'CMBS_10': {'model_accuracy': 0.4895317554473877, 'n_days': 10},
#  'CMF_1': {'model_accuracy': 0.09126628935337067, 'n_days': 1},
#  'CMF_2': {'model_accuracy': 0.1962534487247467, 'n_days': 2},
#  'CMF_5': {'model_accuracy': 0.2027275413274765, 'n_days': 5},
#  'CMF_10': {'model_accuracy': 1.0431920289993286, 'n_days': 10},
#  'CNCE_1': {'model_accuracy': 0.7672635912895203, 'n_days': 1},
#  'CNCE_2': {'model_accuracy': 1.238096833229065, 'n_days': 2},
#  'CNCE_5': {'model_accuracy': 1.4749714136123657, 'n_days': 5},
#  'CNCE_10': {'model_accuracy': 4.955893039703369, 'n_days': 10},
#  'CNK_1': {'model_accuracy': 0.5412648320198059, 'n_days': 1},
#  'CNK_2': {'model_accuracy': 1.1424381732940674, 'n_days': 2},
#  'CNK_5': {'model_accuracy': 2.498626470565796, 'n_days': 5},
#  'CNK_10': {'model_accuracy': 3.974597692489624, 'n_days': 10},
#  'COCP_1': {'model_accuracy': 0.12546038627624512, 'n_days': 1},
#  'COCP_2': {'model_accuracy': 0.2275625467300415, 'n_days': 2},
#  'COCP_5': {'model_accuracy': 0.36087292432785034, 'n_days': 5},
#  'COCP_10': {'model_accuracy': 0.5512491464614868, 'n_days': 10},
#  'COMT_1': {'model_accuracy': 0.17237398028373718, 'n_days': 1},
#  'COMT_2': {'model_accuracy': 0.5182479023933411, 'n_days': 2},
#  'COMT_5': {'model_accuracy': 0.747918426990509, 'n_days': 5},
#  'COMT_10': {'model_accuracy': 1.348375678062439, 'n_days': 10},
#  'COPX_1': {'model_accuracy': 0.9476153254508972, 'n_days': 1},
#  'COPX_2': {'model_accuracy': 0.6227400898933411, 'n_days': 2},
#  'COPX_5': {'model_accuracy': 1.803267240524292, 'n_days': 5},
#  'COPX_10': {'model_accuracy': 2.806236505508423, 'n_days': 10},
#  'CORN_1': {'model_accuracy': 0.050555698573589325, 'n_days': 1},
#  'CORN_2': {'model_accuracy': 0.13831302523612976, 'n_days': 2},
#  'CORN_5': {'model_accuracy': 0.30024662613868713, 'n_days': 5},
#  'CORN_10': {'model_accuracy': 0.39532503485679626, 'n_days': 10},
#  'CORP_1': {'model_accuracy': 0.5049574971199036, 'n_days': 1},
#  'CORP_2': {'model_accuracy': 0.5204482078552246, 'n_days': 2},
#  'CORP_5': {'model_accuracy': 1.1254993677139282, 'n_days': 5},
#  'CORP_10': {'model_accuracy': 2.5456535816192627, 'n_days': 10},
#  'CORR_1': {'model_accuracy': 0.9301897287368774, 'n_days': 1},
#  'CORR_2': {'model_accuracy': 1.1359213590621948, 'n_days': 2},
#  'CORR_5': {'model_accuracy': 2.739731788635254, 'n_days': 5},
#  'CORR_10': {'model_accuracy': 4.464763641357422, 'n_days': 10},
#  'CPER_1': {'model_accuracy': 0.249624565243721, 'n_days': 1},
#  'CPER_2': {'model_accuracy': 0.692938506603241, 'n_days': 2},
#  'CPER_5': {'model_accuracy': 0.4618106782436371, 'n_days': 5},
#  'CPER_10': {'model_accuracy': 1.3580020666122437, 'n_days': 10},
#  'CPHI_1': {'model_accuracy': 0.001377097680233419, 'n_days': 1},
#  'CPHI_2': {'model_accuracy': 0.0019702999852597713, 'n_days': 2},
#  'CPHI_5': {'model_accuracy': 0.0037027716170996428, 'n_days': 5},
#  'CPHI_10': {'model_accuracy': 0.005113460589200258, 'n_days': 10},
#  'CPIX_1': {'model_accuracy': 0.10262937098741531, 'n_days': 1},
#  'CPIX_2': {'model_accuracy': 0.8862084746360779, 'n_days': 2},
#  'CPIX_5': {'model_accuracy': 1.1054099798202515, 'n_days': 5},
#  'CPIX_10': {'model_accuracy': 0.2777273654937744, 'n_days': 10},
#  'CRBP_1': {'model_accuracy': 0.10281961411237717, 'n_days': 1},
#  'CRBP_2': {'model_accuracy': 0.2072531282901764, 'n_days': 2},
#  'CRBP_5': {'model_accuracy': 0.4745059311389923, 'n_days': 5},
#  'CRBP_10': {'model_accuracy': 0.5950220227241516, 'n_days': 10},
#  'CRDF_1': {'model_accuracy': 46.647335052490234, 'n_days': 1},
#  'CRDF_2': {'model_accuracy': 89.8508529663086, 'n_days': 2},
#  'CRDF_5': {'model_accuracy': 221.90213012695312, 'n_days': 5},
#  'CRDF_10': {'model_accuracy': 338.6842346191406, 'n_days': 10},
#  'CREG_1': {'model_accuracy': 0.9589104652404785, 'n_days': 1},
#  'CREG_2': {'model_accuracy': 2.5579898357391357, 'n_days': 2},
#  'CREG_5': {'model_accuracy': 4.753843784332275, 'n_days': 5},
#  'CREG_10': {'model_accuracy': 5.735457897186279, 'n_days': 10},
#  'CRF_1': {'model_accuracy': 0.03139820694923401, 'n_days': 1},
#  'CRF_2': {'model_accuracy': 0.06549115478992462, 'n_days': 2},
#  'CRF_5': {'model_accuracy': 0.18679066002368927, 'n_days': 5},
#  'CRF_10': {'model_accuracy': 0.3124157190322876, 'n_days': 10},
#  'CRNT_1': {'model_accuracy': 0.015702787786722183, 'n_days': 1},
#  'CRNT_2': {'model_accuracy': 0.030124984681606293, 'n_days': 2},
#  'CRNT_5': {'model_accuracy': 0.06942185014486313, 'n_days': 5},
#  'CRNT_10': {'model_accuracy': 0.11723015457391739, 'n_days': 10},
#  'CSIQ_1': {'model_accuracy': 0.850102424621582, 'n_days': 1},
#  'CSIQ_2': {'model_accuracy': 1.6279572248458862, 'n_days': 2},
#  'CSIQ_5': {'model_accuracy': 4.384052753448486, 'n_days': 5},
#  'CSIQ_10': {'model_accuracy': 5.951414108276367, 'n_days': 10},
#  'CSWC_1': {'model_accuracy': 0.12201796472072601, 'n_days': 1},
#  'CSWC_2': {'model_accuracy': 0.16983351111412048, 'n_days': 2},
#  'CSWC_5': {'model_accuracy': 0.4419429302215576, 'n_days': 5},
#  'CSWC_10': {'model_accuracy': 1.1339322328567505, 'n_days': 10},
#  'CURE_1': {'model_accuracy': 3.4907710552215576, 'n_days': 1},
#  'CURE_2': {'model_accuracy': 6.455181121826172, 'n_days': 2},
#  'CURE_5': {'model_accuracy': 17.24568748474121, 'n_days': 5},
#  'CURE_10': {'model_accuracy': 31.232650756835938, 'n_days': 10},
#  'CVM_1': {'model_accuracy': 0.46717730164527893, 'n_days': 1},
#  'CVM_2': {'model_accuracy': 0.787481427192688, 'n_days': 2},
#  'CVM_5': {'model_accuracy': 1.838767647743225, 'n_days': 5},
#  'CVM_10': {'model_accuracy': 2.907996416091919, 'n_days': 10},
#  'CVV_1': {'model_accuracy': 0.06371688097715378, 'n_days': 1},
#  'CVV_2': {'model_accuracy': 0.10147011280059814, 'n_days': 2},
#  'CVV_5': {'model_accuracy': 0.163456529378891, 'n_days': 5},
#  'CVV_10': {'model_accuracy': 0.28081759810447693, 'n_days': 10},
#  'CWI_1': {'model_accuracy': 0.08116396516561508, 'n_days': 1},
#  'CWI_2': {'model_accuracy': 0.13682600855827332, 'n_days': 2},
#  'CWI_5': {'model_accuracy': 0.2792722284793854, 'n_days': 5},
#  'CWI_10': {'model_accuracy': 0.5509547591209412, 'n_days': 10},
#  'CXDC_1': {'model_accuracy': 0.020060576498508453, 'n_days': 1},
#  'CXDC_2': {'model_accuracy': 1.1253867149353027, 'n_days': 2},
#  'CXDC_5': {'model_accuracy': 0.0983688160777092, 'n_days': 5},
#  'CXDC_10': {'model_accuracy': 0.36810147762298584, 'n_days': 10},
#  'CYCC_1': {'model_accuracy': 13.741654396057129, 'n_days': 1},
#  'CYCC_2': {'model_accuracy': 23.64522361755371, 'n_days': 2},
#  'CYCC_5': {'model_accuracy': 49.70280456542969, 'n_days': 5},
#  'CYCC_10': {'model_accuracy': 85.47978210449219, 'n_days': 10},
#  'CYRN_1': {'model_accuracy': 0.007327327970415354, 'n_days': 1},
#  'CYRN_2': {'model_accuracy': 0.04367300122976303, 'n_days': 2},
#  'CYRN_5': {'model_accuracy': 0.015374603681266308, 'n_days': 5},
#  'CYRN_10': {'model_accuracy': 0.038090743124485016, 'n_days': 10},
#  'CYTO_1': {'model_accuracy': 0.42596742510795593, 'n_days': 1},
#  'CYTO_2': {'model_accuracy': 6.556735515594482, 'n_days': 2},
#  'CYTO_5': {'model_accuracy': 0.5462165474891663, 'n_days': 5},
#  'CYTO_10': {'model_accuracy': 0.5084667801856995, 'n_days': 10},
#  'DARE_1': {'model_accuracy': 0.7872232794761658, 'n_days': 1},
#  'DARE_2': {'model_accuracy': 1.1275538206100464, 'n_days': 2},
#  'DARE_5': {'model_accuracy': 2.112614870071411, 'n_days': 5},
#  'DARE_10': {'model_accuracy': 2.621873140335083, 'n_days': 10},
#  'DBEF_1': {'model_accuracy': 0.1965225636959076, 'n_days': 1},
#  'DBEF_2': {'model_accuracy': 0.16851122677326202, 'n_days': 2},
#  'DBEF_5': {'model_accuracy': 0.41250079870224, 'n_days': 5},
#  'DBEF_10': {'model_accuracy': 0.9147990345954895, 'n_days': 10},
#  'DBEU_1': {'model_accuracy': 0.787216067314148, 'n_days': 1},
#  'DBEU_2': {'model_accuracy': 0.17066627740859985, 'n_days': 2},
#  'DBEU_5': {'model_accuracy': 0.3912496268749237, 'n_days': 5},
#  'DBEU_10': {'model_accuracy': 0.9659686088562012, 'n_days': 10},
#  'DBVT_1': {'model_accuracy': 0.6849772930145264, 'n_days': 1},
#  'DBVT_2': {'model_accuracy': 1.1768600940704346, 'n_days': 2},
#  'DBVT_5': {'model_accuracy': 2.803694248199463, 'n_days': 5},
#  'DBVT_10': {'model_accuracy': 6.005731582641602, 'n_days': 10},
#  'DDM_1': {'model_accuracy': 0.9000555872917175, 'n_days': 1},
#  'DDM_2': {'model_accuracy': 1.6321896314620972, 'n_days': 2},
#  'DDM_5': {'model_accuracy': 3.6904478073120117, 'n_days': 5},
#  'DDM_10': {'model_accuracy': 8.254181861877441, 'n_days': 10},
#  'DDS_1': {'model_accuracy': 20.64860725402832, 'n_days': 1},
#  'DDS_2': {'model_accuracy': 48.32846450805664, 'n_days': 2},
#  'DDS_5': {'model_accuracy': 126.39034271240234, 'n_days': 5},
#  'DDS_10': {'model_accuracy': 280.06988525390625, 'n_days': 10},
#  'DFJ_1': {'model_accuracy': 1.2540946006774902, 'n_days': 1},
#  'DFJ_2': {'model_accuracy': 1.8012537956237793, 'n_days': 2},
#  'DFJ_5': {'model_accuracy': 2.7360448837280273, 'n_days': 5},
#  'DFJ_10': {'model_accuracy': 4.603964805603027, 'n_days': 10},
#  'DGLY_1': {'model_accuracy': 0.031940944492816925, 'n_days': 1},
#  'DGLY_2': {'model_accuracy': 0.05193652957677841, 'n_days': 2},
#  'DGLY_5': {'model_accuracy': 0.09789127856492996, 'n_days': 5},
#  'DGLY_10': {'model_accuracy': 0.19908469915390015, 'n_days': 10},
#  'DGS_1': {'model_accuracy': 0.24959126114845276, 'n_days': 1},
#  'DGS_2': {'model_accuracy': 0.42210227251052856, 'n_days': 2},
#  'DGS_5': {'model_accuracy': 1.2111666202545166, 'n_days': 5},
#  'DGS_10': {'model_accuracy': 2.255502700805664, 'n_days': 10},
#  'DHY_1': {'model_accuracy': 0.0006269366131164134, 'n_days': 1},
#  'DHY_2': {'model_accuracy': 0.0010576474014669657, 'n_days': 2},
#  'DHY_5': {'model_accuracy': 0.0021736903581768274, 'n_days': 5},
#  'DHY_10': {'model_accuracy': 0.00359988771378994, 'n_days': 10},
#  'DIA_1': {'model_accuracy': 100.47262573242188, 'n_days': 1},
#  'DIA_2': {'model_accuracy': 56.51513671875, 'n_days': 2},
#  'DIA_5': {'model_accuracy': 53.98048782348633, 'n_days': 5},
#  'DIA_10': {'model_accuracy': 78.83961486816406, 'n_days': 10},
#  'DIV_1': {'model_accuracy': 0.10089293122291565, 'n_days': 1},
#  'DIV_2': {'model_accuracy': 0.167101189494133, 'n_days': 2},
#  'DIV_5': {'model_accuracy': 0.24354304373264313, 'n_days': 5},
#  'DIV_10': {'model_accuracy': 0.4016406238079071, 'n_days': 10},
#  'DMRC_1': {'model_accuracy': 1.7329473495483398, 'n_days': 1},
#  'DMRC_2': {'model_accuracy': 3.5070858001708984, 'n_days': 2},
#  'DMRC_5': {'model_accuracy': 8.226666450500488, 'n_days': 5},
#  'DMRC_10': {'model_accuracy': 15.363298416137695, 'n_days': 10},
#  'DNN_1': {'model_accuracy': 0.0016067060641944408, 'n_days': 1},
#  'DNN_2': {'model_accuracy': 0.01748407818377018, 'n_days': 2},
#  'DNN_5': {'model_accuracy': 0.011380095034837723, 'n_days': 5},
#  'DNN_10': {'model_accuracy': 0.012161093764007092, 'n_days': 10},
#  'DRIP_1': {'model_accuracy': 117.44669342041016, 'n_days': 1},
#  'DRIP_2': {'model_accuracy': 218.92677307128906, 'n_days': 2},
#  'DRIP_5': {'model_accuracy': 457.5537109375, 'n_days': 5},
#  'DRIP_10': {'model_accuracy': 697.5988159179688, 'n_days': 10},
#  'DRN_1': {'model_accuracy': 0.43392235040664673, 'n_days': 1},
#  'DRN_2': {'model_accuracy': 0.9032407999038696, 'n_days': 2},
#  'DRN_5': {'model_accuracy': 2.355048656463623, 'n_days': 5},
#  'DRN_10': {'model_accuracy': 4.909763813018799, 'n_days': 10},
#  'DRRX_1': {'model_accuracy': 0.007551686838269234, 'n_days': 1},
#  'DRRX_2': {'model_accuracy': 0.011624589562416077, 'n_days': 2},
#  'DRRX_5': {'model_accuracy': 0.028559666126966476, 'n_days': 5},
#  'DRRX_10': {'model_accuracy': 0.048744067549705505, 'n_days': 10},
#  'DRV_1': {'model_accuracy': 4016.15185546875, 'n_days': 1},
#  'DRV_2': {'model_accuracy': 1003.9627685546875, 'n_days': 2},
#  'DRV_5': {'model_accuracy': 2293.545654296875, 'n_days': 5},
#  'DRV_10': {'model_accuracy': 1999.51171875, 'n_days': 10},
#  'DRW_1': {'model_accuracy': 0.11885911226272583, 'n_days': 1},
#  'DRW_2': {'model_accuracy': 0.1981348693370819, 'n_days': 2},
#  'DRW_5': {'model_accuracy': 0.49322226643562317, 'n_days': 5},
#  'DRW_10': {'model_accuracy': 0.9346492886543274, 'n_days': 10},
#  'DS_1': {'model_accuracy': 0.018450474366545677, 'n_days': 1},
#  'DS_2': {'model_accuracy': 0.034004177898168564, 'n_days': 2},
#  'DS_5': {'model_accuracy': 0.06602407246828079, 'n_days': 5},
#  'DS_10': {'model_accuracy': 0.1285918802022934, 'n_days': 10},
#  'DSI_1': {'model_accuracy': 1.2633484601974487, 'n_days': 1},
#  'DSI_2': {'model_accuracy': 7.543466567993164, 'n_days': 2},
#  'DSI_5': {'model_accuracy': 3.1751108169555664, 'n_days': 5},
#  'DSI_10': {'model_accuracy': 10.007548332214355, 'n_days': 10},
#  'DTEA_1': {'model_accuracy': 0.02865602634847164, 'n_days': 1},
#  'DTEA_2': {'model_accuracy': 0.05873790383338928, 'n_days': 2},
#  'DTEA_5': {'model_accuracy': 0.13658151030540466, 'n_days': 5},
#  'DTEA_10': {'model_accuracy': 0.21643179655075073, 'n_days': 10},
#  'DTH_1': {'model_accuracy': 0.18470141291618347, 'n_days': 1},
#  'DTH_2': {'model_accuracy': 0.33466821908950806, 'n_days': 2},
#  'DTH_5': {'model_accuracy': 0.788019597530365, 'n_days': 5},
#  'DTH_10': {'model_accuracy': 1.458463191986084, 'n_days': 10},
#  'DUG_1': {'model_accuracy': 279.8099060058594, 'n_days': 1},
#  'DUG_2': {'model_accuracy': 317.9588623046875, 'n_days': 2},
#  'DUG_5': {'model_accuracy': 790.1536865234375, 'n_days': 5},
#  'DUG_10': {'model_accuracy': 1586.943603515625, 'n_days': 10},
#  'DVYE_1': {'model_accuracy': 0.28186580538749695, 'n_days': 1},
#  'DVYE_2': {'model_accuracy': 0.3337825536727905, 'n_days': 2},
#  'DVYE_5': {'model_accuracy': 0.803340494632721, 'n_days': 5},
#  'DVYE_10': {'model_accuracy': 1.61527681350708, 'n_days': 10},
#  'DWX_1': {'model_accuracy': 0.16415084898471832, 'n_days': 1},
#  'DWX_2': {'model_accuracy': 0.31483912467956543, 'n_days': 2},
#  'DWX_5': {'model_accuracy': 0.5768149495124817, 'n_days': 5},
#  'DWX_10': {'model_accuracy': 1.1666162014007568, 'n_days': 10},
#  'DXD_1': {'model_accuracy': 93.11419677734375, 'n_days': 1},
#  'DXD_2': {'model_accuracy': 61.930667877197266, 'n_days': 2},
#  'DXD_5': {'model_accuracy': 134.91514587402344, 'n_days': 5},
#  'DXD_10': {'model_accuracy': 172.7813262939453, 'n_days': 10},
#  'DXJ_1': {'model_accuracy': 0.46911105513572693, 'n_days': 1},
#  'DXJ_2': {'model_accuracy': 0.7445976138114929, 'n_days': 2},
#  'DXJ_5': {'model_accuracy': 1.7757527828216553, 'n_days': 5},
#  'DXJ_10': {'model_accuracy': 3.3521969318389893, 'n_days': 10},
#  'DXLG_1': {'model_accuracy': 0.019265124574303627, 'n_days': 1},
#  'DXLG_2': {'model_accuracy': 0.028133459389209747, 'n_days': 2},
#  'DXLG_5': {'model_accuracy': 0.07465775310993195, 'n_days': 5},
#  'DXLG_10': {'model_accuracy': 0.12553609907627106, 'n_days': 10},
#  'DYAI_1': {'model_accuracy': 0.44409283995628357, 'n_days': 1},
#  'DYAI_2': {'model_accuracy': 0.2782425284385681, 'n_days': 2},
#  'DYAI_5': {'model_accuracy': 0.1487283706665039, 'n_days': 5},
#  'DYAI_10': {'model_accuracy': 0.26463887095451355, 'n_days': 10},
#  'EARN_1': {'model_accuracy': 0.04596075043082237, 'n_days': 1},
#  'EARN_2': {'model_accuracy': 0.09730076789855957, 'n_days': 2},
#  'EARN_5': {'model_accuracy': 0.25004759430885315, 'n_days': 5},
#  'EARN_10': {'model_accuracy': 0.3707807958126068, 'n_days': 10},
#  'ECH_1': {'model_accuracy': 0.40046197175979614, 'n_days': 1},
#  'ECH_2': {'model_accuracy': 0.7437796592712402, 'n_days': 2},
#  'ECH_5': {'model_accuracy': 2.151587963104248, 'n_days': 5},
#  'ECH_10': {'model_accuracy': 3.572603940963745, 'n_days': 10},
#  'EDIV_1': {'model_accuracy': 0.18035680055618286, 'n_days': 1},
#  'EDIV_2': {'model_accuracy': 0.2656177878379822, 'n_days': 2},
#  'EDIV_5': {'model_accuracy': 0.5033674240112305, 'n_days': 5},
#  'EDIV_10': {'model_accuracy': 0.9708935618400574, 'n_days': 10},
#  'EDN_1': {'model_accuracy': 0.5851298570632935, 'n_days': 1},
#  'EDN_2': {'model_accuracy': 0.967414915561676, 'n_days': 2},
#  'EDN_5': {'model_accuracy': 2.4670257568359375, 'n_days': 5},
#  'EDN_10': {'model_accuracy': 4.963284492492676, 'n_days': 10},
#  'EDSA_1': {'model_accuracy': 20.955644607543945, 'n_days': 1},
#  'EDSA_2': {'model_accuracy': 29.036258697509766, 'n_days': 2},
#  'EDSA_5': {'model_accuracy': 46.05510711669922, 'n_days': 5},
#  'EDSA_10': {'model_accuracy': 56.52631378173828, 'n_days': 10},
#  'EDV_1': {'model_accuracy': 3.9463846683502197, 'n_days': 1},
#  'EDV_2': {'model_accuracy': 5.911626815795898, 'n_days': 2},
#  'EDV_5': {'model_accuracy': 16.98764419555664, 'n_days': 5},
#  'EDV_10': {'model_accuracy': 18.364646911621094, 'n_days': 10},
#  'EDZ_1': {'model_accuracy': 8.399145126342773, 'n_days': 1},
#  'EDZ_2': {'model_accuracy': 16.03438377380371, 'n_days': 2},
#  'EDZ_5': {'model_accuracy': 26.408985137939453, 'n_days': 5},
#  'EDZ_10': {'model_accuracy': 42.65629196166992, 'n_days': 10},
#  'EELV_1': {'model_accuracy': 0.07455813139677048, 'n_days': 1},
#  'EELV_2': {'model_accuracy': 0.10470665246248245, 'n_days': 2},
#  'EELV_5': {'model_accuracy': 0.19203688204288483, 'n_days': 5},
#  'EELV_10': {'model_accuracy': 0.3741459846496582, 'n_days': 10},
#  'EEM_1': {'model_accuracy': 0.3089437186717987, 'n_days': 1},
#  'EEM_2': {'model_accuracy': 0.5534238815307617, 'n_days': 2},
#  'EEM_5': {'model_accuracy': 1.309528112411499, 'n_days': 5},
#  'EEM_10': {'model_accuracy': 2.2793750762939453, 'n_days': 10},
#  'EEMS_1': {'model_accuracy': 0.842143177986145, 'n_days': 1},
#  'EEMS_2': {'model_accuracy': 0.5150726437568665, 'n_days': 2},
#  'EEMS_5': {'model_accuracy': 1.3180365562438965, 'n_days': 5},
#  'EEMS_10': {'model_accuracy': 2.832364559173584, 'n_days': 10},
#  'EES_1': {'model_accuracy': 0.2711936831474304, 'n_days': 1},
#  'EES_2': {'model_accuracy': 0.9417290687561035, 'n_days': 2},
#  'EES_5': {'model_accuracy': 1.454788327217102, 'n_days': 5},
#  'EES_10': {'model_accuracy': 2.3205173015594482, 'n_days': 10},
#  'EEV_1': {'model_accuracy': 2.0841012001037598, 'n_days': 1},
#  'EEV_2': {'model_accuracy': 3.4316964149475098, 'n_days': 2},
#  'EEV_5': {'model_accuracy': 6.951834201812744, 'n_days': 5},
#  'EEV_10': {'model_accuracy': 12.183991432189941, 'n_days': 10},
#  'EFA_1': {'model_accuracy': 0.47528478503227234, 'n_days': 1},
#  'EFA_2': {'model_accuracy': 1.102113962173462, 'n_days': 2},
#  'EFA_5': {'model_accuracy': 2.507671594619751, 'n_days': 5},
#  'EFA_10': {'model_accuracy': 3.732320785522461, 'n_days': 10},
#  'EFG_1': {'model_accuracy': 13.84835433959961, 'n_days': 1},
#  'EFG_2': {'model_accuracy': 2.3620285987854004, 'n_days': 2},
#  'EFG_5': {'model_accuracy': 24.346378326416016, 'n_days': 5},
# ...
#  'EFV_10': {'model_accuracy': 3.8484840393066406, 'n_days': 10},
#  'EIDO_1': {'model_accuracy': 0.13233423233032227, 'n_days': 1},
#  'EIDO_2': {'model_accuracy': 0.2709749937057495, 'n_days': 2},
#  'EIDO_5': {'model_accuracy': 0.5485538244247437, 'n_days': 5},
#  'EIDO_10': {'model_accuracy': 1.238620638847351, 'n_days': 10},
#  'EIRL_1': {'model_accuracy': 0.6638049483299255, 'n_days': 1},
#  'EIRL_2': {'model_accuracy': 0.7695009708404541, 'n_days': 2},
#  'EIRL_5': {'model_accuracy': 1.8512710332870483, 'n_days': 5},
#  'EIRL_10': {'model_accuracy': 3.2349002361297607, 'n_days': 10},
#  'EIS_1': {'model_accuracy': 0.7977433204650879, 'n_days': 1},
#  'EIS_2': {'model_accuracy': 0.9529073238372803, 'n_days': 2},
#  'EIS_5': {'model_accuracy': 2.5238471031188965, 'n_days': 5},
#  'EIS_10': {'model_accuracy': 4.905451774597168, 'n_days': 10},
#  'ELA_1': {'model_accuracy': 0.4231562912464142, 'n_days': 1},
#  'ELA_2': {'model_accuracy': 0.7951579689979553, 'n_days': 2},
#  'ELA_5': {'model_accuracy': 1.3866103887557983, 'n_days': 5},
#  'ELA_10': {'model_accuracy': 1.1666709184646606, 'n_days': 10},
#  'ELD_1': {'model_accuracy': 0.18445225059986115, 'n_days': 1},
#  'ELD_2': {'model_accuracy': 0.31128376722335815, 'n_days': 2},
#  'ELD_5': {'model_accuracy': 0.34408003091812134, 'n_days': 5},
#  'ELD_10': {'model_accuracy': 0.5802475810050964, 'n_days': 10},
#  'EMAN_1': {'model_accuracy': 0.010182326659560204, 'n_days': 1},
#  'EMAN_2': {'model_accuracy': 0.018982484936714172, 'n_days': 2},
#  'EMAN_5': {'model_accuracy': 0.035591911524534225, 'n_days': 5},
#  'EMAN_10': {'model_accuracy': 0.061195194721221924, 'n_days': 10},
#  'EMB_1': {'model_accuracy': 2.0454025268554688, 'n_days': 1},
#  'EMB_2': {'model_accuracy': 11.215865135192871, 'n_days': 2},
#  'EMB_5': {'model_accuracy': 118.2011947631836, 'n_days': 5},
#  'EMB_10': {'model_accuracy': 11.945144653320312, 'n_days': 10},
#  'EMHY_1': {'model_accuracy': 0.26955917477607727, 'n_days': 1},
#  'EMHY_2': {'model_accuracy': 0.18097738921642303, 'n_days': 2},
#  'EMHY_5': {'model_accuracy': 0.6003373861312866, 'n_days': 5},
#  'EMHY_10': {'model_accuracy': 0.7932100296020508, 'n_days': 10},
#  'EMLP_1': {'model_accuracy': 0.08575307577848434, 'n_days': 1},
#  'EMLP_2': {'model_accuracy': 0.1164223700761795, 'n_days': 2},
#  'EMLP_5': {'model_accuracy': 0.2955281436443329, 'n_days': 5},
#  'EMLP_10': {'model_accuracy': 0.5539149045944214, 'n_days': 10},
#  'ENG_1': {'model_accuracy': 0.02101387269794941, 'n_days': 1},
#  'ENG_2': {'model_accuracy': 0.03305024281144142, 'n_days': 2},
#  'ENG_5': {'model_accuracy': 0.07490216940641403, 'n_days': 5},
#  'ENG_10': {'model_accuracy': 0.14009970426559448, 'n_days': 10},
#  'ENLV_1': {'model_accuracy': 25.59573745727539, 'n_days': 1},
#  'ENLV_2': {'model_accuracy': 32.01653289794922, 'n_days': 2},
#  'ENLV_5': {'model_accuracy': 27.98292350769043, 'n_days': 5},
#  'ENLV_10': {'model_accuracy': 17.688024520874023, 'n_days': 10},
#  'ENSV_1': {'model_accuracy': 0.19772794842720032, 'n_days': 1},
#  'ENSV_2': {'model_accuracy': 0.2847508192062378, 'n_days': 2},
#  'ENSV_5': {'model_accuracy': 0.5937073826789856, 'n_days': 5},
#  'ENSV_10': {'model_accuracy': 0.8943567276000977, 'n_days': 10},
#  'ENZL_1': {'model_accuracy': 1.2802879810333252, 'n_days': 1},
#  'ENZL_2': {'model_accuracy': 1.703735113143921, 'n_days': 2},
#  'ENZL_5': {'model_accuracy': 2.6976630687713623, 'n_days': 5},
#  'ENZL_10': {'model_accuracy': 5.095755577087402, 'n_days': 10},
#  'EPHE_1': {'model_accuracy': 0.399242103099823, 'n_days': 1},
#  'EPHE_2': {'model_accuracy': 1.0740966796875, 'n_days': 2},
#  'EPHE_5': {'model_accuracy': 1.3263092041015625, 'n_days': 5},
#  'EPHE_10': {'model_accuracy': 2.422389030456543, 'n_days': 10},
#  'EPOL_1': {'model_accuracy': 0.502656102180481, 'n_days': 1},
#  'EPOL_2': {'model_accuracy': 0.2763597071170807, 'n_days': 2},
#  'EPOL_5': {'model_accuracy': 0.9071208834648132, 'n_days': 5},
#  'EPOL_10': {'model_accuracy': 0.9745364189147949, 'n_days': 10},
#  'EPP_1': {'model_accuracy': 0.31652548909187317, 'n_days': 1},
#  'EPP_2': {'model_accuracy': 0.4435129165649414, 'n_days': 2},
#  'EPP_5': {'model_accuracy': 1.1053929328918457, 'n_days': 5},
#  'EPP_10': {'model_accuracy': 2.1324212551116943, 'n_days': 10},
#  'EPU_1': {'model_accuracy': 2.8753771781921387, 'n_days': 1},
#  'EPU_2': {'model_accuracy': 0.4959939122200012, 'n_days': 2},
#  'EPU_5': {'model_accuracy': 3.8831779956817627, 'n_days': 5},
#  'EPU_10': {'model_accuracy': 2.535554885864258, 'n_days': 10},
#  'EQAL_1': {'model_accuracy': 1.1728730201721191, 'n_days': 1},
#  'EQAL_2': {'model_accuracy': 1.8054331541061401, 'n_days': 2},
#  'EQAL_5': {'model_accuracy': 1.8505779504776, 'n_days': 5},
#  'EQAL_10': {'model_accuracy': 2.424382209777832, 'n_days': 10},
#  'ERUS_1': {'model_accuracy': 0.4491744041442871, 'n_days': 1},
#  'ERUS_2': {'model_accuracy': 0.7661178708076477, 'n_days': 2},
#  'ERUS_5': {'model_accuracy': 2.046562910079956, 'n_days': 5},
#  'ERUS_10': {'model_accuracy': 3.473123550415039, 'n_days': 10},
#  'ERY_1': {'model_accuracy': 41.18430709838867, 'n_days': 1},
#  'ERY_2': {'model_accuracy': 43.89508819580078, 'n_days': 2},
#  'ERY_5': {'model_accuracy': 105.25447845458984, 'n_days': 5},
#  'ERY_10': {'model_accuracy': 229.81536865234375, 'n_days': 10},
#  'ESGC_1': {'model_accuracy': 0.17053748667240143, 'n_days': 1},
#  'ESGC_2': {'model_accuracy': 0.3610897660255432, 'n_days': 2},
#  'ESGC_5': {'model_accuracy': 0.7351537346839905, 'n_days': 5},
#  'ESGC_10': {'model_accuracy': 1.0237497091293335, 'n_days': 10},
#  'ESPR_1': {'model_accuracy': 3.3139824867248535, 'n_days': 1},
#  'ESPR_2': {'model_accuracy': 6.291489601135254, 'n_days': 2},
#  'ESPR_5': {'model_accuracy': 14.428969383239746, 'n_days': 5},
#  'ESPR_10': {'model_accuracy': 27.725587844848633, 'n_days': 10},
#  'EUFN_1': {'model_accuracy': 0.07697088271379471, 'n_days': 1},
#  'EUFN_2': {'model_accuracy': 0.14573600888252258, 'n_days': 2},
#  'EUFN_5': {'model_accuracy': 0.36671239137649536, 'n_days': 5},
#  'EUFN_10': {'model_accuracy': 0.6545888781547546, 'n_days': 10},
#  'EUM_1': {'model_accuracy': 0.13264696300029755, 'n_days': 1},
#  'EUM_2': {'model_accuracy': 0.1154870092868805, 'n_days': 2},
#  'EUM_5': {'model_accuracy': 0.28327053785324097, 'n_days': 5},
#  'EUM_10': {'model_accuracy': 0.4692457318305969, 'n_days': 10},
#  'EUO_1': {'model_accuracy': 0.06288634240627289, 'n_days': 1},
#  'EUO_2': {'model_accuracy': 0.09620444476604462, 'n_days': 2},
#  'EUO_5': {'model_accuracy': 0.22276538610458374, 'n_days': 5},
#  'EUO_10': {'model_accuracy': 0.3664223849773407, 'n_days': 10},
#  'EURL_1': {'model_accuracy': 0.6654892563819885, 'n_days': 1},
#  'EURL_2': {'model_accuracy': 1.2840585708618164, 'n_days': 2},
#  'EURL_5': {'model_accuracy': 3.204191207885742, 'n_days': 5},
#  'EURL_10': {'model_accuracy': 6.600316047668457, 'n_days': 10},
#  'EURN_1': {'model_accuracy': 0.04984032362699509, 'n_days': 1},
#  'EURN_2': {'model_accuracy': 0.09506608545780182, 'n_days': 2},
#  'EURN_5': {'model_accuracy': 0.17713318765163422, 'n_days': 5},
#  'EURN_10': {'model_accuracy': 0.32036900520324707, 'n_days': 10},
#  'EVFM_1': {'model_accuracy': 0.18897360563278198, 'n_days': 1},
#  'EVFM_2': {'model_accuracy': 0.3037656545639038, 'n_days': 2},
#  'EVFM_5': {'model_accuracy': 0.9135527610778809, 'n_days': 5},
#  'EVFM_10': {'model_accuracy': 0.8494674563407898, 'n_days': 10},
#  'EVOL_1': {'model_accuracy': 0.009883948601782322, 'n_days': 1},
#  'EVOL_2': {'model_accuracy': 0.019365616142749786, 'n_days': 2},
#  'EVOL_5': {'model_accuracy': 0.032124195247888565, 'n_days': 5},
#  'EVOL_10': {'model_accuracy': 0.049896493554115295, 'n_days': 10},
#  'EWA_1': {'model_accuracy': 0.09989576041698456, 'n_days': 1},
#  'EWA_2': {'model_accuracy': 0.13067124783992767, 'n_days': 2},
#  'EWA_5': {'model_accuracy': 0.29903438687324524, 'n_days': 5},
#  'EWA_10': {'model_accuracy': 0.5599827766418457, 'n_days': 10},
#  'EWC_1': {'model_accuracy': 0.3918040990829468, 'n_days': 1},
#  'EWC_2': {'model_accuracy': 0.33721140027046204, 'n_days': 2},
#  'EWC_5': {'model_accuracy': 0.8398926854133606, 'n_days': 5},
#  'EWC_10': {'model_accuracy': 1.7841473817825317, 'n_days': 10},
#  'EWD_1': {'model_accuracy': 0.2980998456478119, 'n_days': 1},
#  'EWD_2': {'model_accuracy': 0.7381407618522644, 'n_days': 2},
#  'EWD_5': {'model_accuracy': 1.0476422309875488, 'n_days': 5},
#  'EWD_10': {'model_accuracy': 1.950286865234375, 'n_days': 10},
#  'EWG_1': {'model_accuracy': 0.13387484848499298, 'n_days': 1},
#  'EWG_2': {'model_accuracy': 0.2604621350765228, 'n_days': 2},
#  'EWG_5': {'model_accuracy': 0.6253155469894409, 'n_days': 5},
#  'EWG_10': {'model_accuracy': 1.1276829242706299, 'n_days': 10},
#  'EWH_1': {'model_accuracy': 0.08454956114292145, 'n_days': 1},
#  'EWH_2': {'model_accuracy': 0.1427650898694992, 'n_days': 2},
#  'EWH_5': {'model_accuracy': 0.36755216121673584, 'n_days': 5},
#  'EWH_10': {'model_accuracy': 0.6289674043655396, 'n_days': 10},
#  'EWK_1': {'model_accuracy': 0.05871186405420303, 'n_days': 1},
#  'EWK_2': {'model_accuracy': 0.11479461193084717, 'n_days': 2},
#  'EWK_5': {'model_accuracy': 0.24117827415466309, 'n_days': 5},
#  'EWK_10': {'model_accuracy': 0.4531363844871521, 'n_days': 10},
#  'EWL_1': {'model_accuracy': 0.6988288760185242, 'n_days': 1},
#  'EWL_2': {'model_accuracy': 2.3659181594848633, 'n_days': 2},
#  'EWL_5': {'model_accuracy': 2.0756781101226807, 'n_days': 5},
#  'EWL_10': {'model_accuracy': 1.286025881767273, 'n_days': 10},
#  'EWN_1': {'model_accuracy': 0.21334974467754364, 'n_days': 1},
#  'EWN_2': {'model_accuracy': 0.9805785417556763, 'n_days': 2},
#  'EWN_5': {'model_accuracy': 1.067698359489441, 'n_days': 5},
#  'EWN_10': {'model_accuracy': 1.5766469240188599, 'n_days': 10},
#  'EWO_1': {'model_accuracy': 0.07077945023775101, 'n_days': 1},
#  'EWO_2': {'model_accuracy': 0.12950992584228516, 'n_days': 2},
#  'EWO_5': {'model_accuracy': 0.3524821102619171, 'n_days': 5},
#  'EWO_10': {'model_accuracy': 0.7445706129074097, 'n_days': 10},
#  'EWP_1': {'model_accuracy': 0.17668016254901886, 'n_days': 1},
#  'EWP_2': {'model_accuracy': 0.29098430275917053, 'n_days': 2},
#  'EWP_5': {'model_accuracy': 0.626051664352417, 'n_days': 5},
#  'EWP_10': {'model_accuracy': 1.2589927911758423, 'n_days': 10},
#  'EWQ_1': {'model_accuracy': 0.2477918267250061, 'n_days': 1},
#  'EWQ_2': {'model_accuracy': 0.279263436794281, 'n_days': 2},
#  'EWQ_5': {'model_accuracy': 0.67437344789505, 'n_days': 5},
#  'EWQ_10': {'model_accuracy': 1.263193130493164, 'n_days': 10},
#  'EWW_1': {'model_accuracy': 0.5259507298469543, 'n_days': 1},
#  'EWW_2': {'model_accuracy': 1.0105578899383545, 'n_days': 2},
#  'EWW_5': {'model_accuracy': 2.1718478202819824, 'n_days': 5},
#  'EWW_10': {'model_accuracy': 3.805908441543579, 'n_days': 10},
#  'EWY_1': {'model_accuracy': 0.9830096960067749, 'n_days': 1},
#  'EWY_2': {'model_accuracy': 3545.064453125, 'n_days': 2},
#  'EWY_5': {'model_accuracy': 4.2594451904296875, 'n_days': 5},
#  'EWY_10': {'model_accuracy': 7.767110347747803, 'n_days': 10},
#  'EWZ_1': {'model_accuracy': 0.6203746795654297, 'n_days': 1},
#  'EWZ_2': {'model_accuracy': 1.0494970083236694, 'n_days': 2},
#  'EWZ_5': {'model_accuracy': 2.3694334030151367, 'n_days': 5},
#  'EWZ_10': {'model_accuracy': 4.4925971031188965, 'n_days': 10},
#  'EXI_1': {'model_accuracy': 8.889884948730469, 'n_days': 1},
#  'EXI_2': {'model_accuracy': 12.731780052185059, 'n_days': 2},
#  'EXI_5': {'model_accuracy': 12.615796089172363, 'n_days': 5},
#  'EXI_10': {'model_accuracy': 19.078962326049805, 'n_days': 10},
#  'EXK_1': {'model_accuracy': 0.02471872977912426, 'n_days': 1},
#  'EXK_2': {'model_accuracy': 0.045988500118255615, 'n_days': 2},
#  'EXK_5': {'model_accuracy': 0.10510804504156113, 'n_days': 5},
#  'EXK_10': {'model_accuracy': 0.16336260735988617, 'n_days': 10},
#  'EXPR_1': {'model_accuracy': 0.1120622381567955, 'n_days': 1},
#  'EXPR_2': {'model_accuracy': 0.1843515783548355, 'n_days': 2},
#  'EXPR_5': {'model_accuracy': 0.43733155727386475, 'n_days': 5},
#  'EXPR_10': {'model_accuracy': 0.7407010197639465, 'n_days': 10},
#  'EYEG_1': {'model_accuracy': 1.6593328714370728, 'n_days': 1},
#  'EYEG_2': {'model_accuracy': 2.8542168140411377, 'n_days': 2},
#  'EYEG_5': {'model_accuracy': 3.9512221813201904, 'n_days': 5},
#  'EYEG_10': {'model_accuracy': 7.034385681152344, 'n_days': 10},
#  'EZA_1': {'model_accuracy': 1.404410719871521, 'n_days': 1},
#  'EZA_2': {'model_accuracy': 2.222705602645874, 'n_days': 2},
#  'EZA_5': {'model_accuracy': 4.375392913818359, 'n_days': 5},
#  'EZA_10': {'model_accuracy': 7.104236602783203, 'n_days': 10},
#  'EZU_1': {'model_accuracy': 0.22156521677970886, 'n_days': 1},
#  'EZU_2': {'model_accuracy': 0.6510592103004456, 'n_days': 2},
#  'EZU_5': {'model_accuracy': 2.0606958866119385, 'n_days': 5},
#  'EZU_10': {'model_accuracy': 2.4872872829437256, 'n_days': 10},
#  'FAM_1': {'model_accuracy': 0.0331980437040329, 'n_days': 1},
#  'FAM_2': {'model_accuracy': 0.016130356118083, 'n_days': 2},
#  'FAM_5': {'model_accuracy': 0.03698670491576195, 'n_days': 5},
#  'FAM_10': {'model_accuracy': 0.06130467727780342, 'n_days': 10},
#  'FAN_1': {'model_accuracy': 0.06351106613874435, 'n_days': 1},
#  'FAN_2': {'model_accuracy': 0.07425105571746826, 'n_days': 2},
#  'FAN_5': {'model_accuracy': 0.2116132527589798, 'n_days': 5},
#  'FAN_10': {'model_accuracy': 0.4195539355278015, 'n_days': 10},
#  'FAS_1': {'model_accuracy': 5.82411003112793, 'n_days': 1},
#  'FAS_2': {'model_accuracy': 12.233705520629883, 'n_days': 2},
#  'FAS_5': {'model_accuracy': 29.813234329223633, 'n_days': 5},
#  'FAS_10': {'model_accuracy': 77.45156860351562, 'n_days': 10},
#  'FCO_1': {'model_accuracy': 0.011341696605086327, 'n_days': 1},
#  'FCO_2': {'model_accuracy': 0.021691374480724335, 'n_days': 2},
#  'FCO_5': {'model_accuracy': 0.050788864493370056, 'n_days': 5},
#  'FCO_10': {'model_accuracy': 0.10864958167076111, 'n_days': 10},
#  'FCOM_1': {'model_accuracy': 0.20000605285167694, 'n_days': 1},
#  'FCOM_2': {'model_accuracy': 0.46255144476890564, 'n_days': 2},
#  'FCOM_5': {'model_accuracy': 0.8776559829711914, 'n_days': 5},
#  'FCOM_10': {'model_accuracy': 1.7095130681991577, 'n_days': 10},
#  'FDD_1': {'model_accuracy': 0.0236110370606184, 'n_days': 1},
#  'FDD_2': {'model_accuracy': 0.05703658610582352, 'n_days': 2},
#  'FDD_5': {'model_accuracy': 0.10337626188993454, 'n_days': 5},
#  'FDD_10': {'model_accuracy': 0.22095899283885956, 'n_days': 10},
#  'FDIS_1': {'model_accuracy': 0.7130343914031982, 'n_days': 1},
#  'FDIS_2': {'model_accuracy': 2.9693996906280518, 'n_days': 2},
#  'FDIS_5': {'model_accuracy': 2.2499582767486572, 'n_days': 5},
#  'FDIS_10': {'model_accuracy': 4.384525299072266, 'n_days': 10},
#  'FDL_1': {'model_accuracy': 0.1323011964559555, 'n_days': 1},
#  'FDL_2': {'model_accuracy': 0.1831597238779068, 'n_days': 2},
#  'FDL_5': {'model_accuracy': 0.4780391454696655, 'n_days': 5},
#  'FDL_10': {'model_accuracy': 0.7656732201576233, 'n_days': 10},
#  'FDT_1': {'model_accuracy': 0.3691920042037964, 'n_days': 1},
#  'FDT_2': {'model_accuracy': 0.786492645740509, 'n_days': 2},
#  'FDT_5': {'model_accuracy': 1.8017126321792603, 'n_days': 5},
#  'FDT_10': {'model_accuracy': 3.1522343158721924, 'n_days': 10},
#  'FEM_1': {'model_accuracy': 0.11901582032442093, 'n_days': 1},
#  'FEM_2': {'model_accuracy': 0.1966443806886673, 'n_days': 2},
#  'FEM_5': {'model_accuracy': 0.434868723154068, 'n_days': 5},
#  'FEM_10': {'model_accuracy': 0.8419000506401062, 'n_days': 10},
#  'FEMS_1': {'model_accuracy': 0.23429307341575623, 'n_days': 1},
#  'FEMS_2': {'model_accuracy': 0.629635751247406, 'n_days': 2},
#  'FEMS_5': {'model_accuracy': 1.08370041847229, 'n_days': 5},
#  'FEMS_10': {'model_accuracy': 2.2792510986328125, 'n_days': 10},
#  'FENG_1': {'model_accuracy': 0.027214406058192253, 'n_days': 1},
#  'FENG_2': {'model_accuracy': 0.04197343811392784, 'n_days': 2},
#  'FENG_5': {'model_accuracy': 0.08271767199039459, 'n_days': 5},
#  'FENG_10': {'model_accuracy': 0.1482139676809311, 'n_days': 10},
#  'FENY_1': {'model_accuracy': 0.08289918303489685, 'n_days': 1},
#  'FENY_2': {'model_accuracy': 0.1516330987215042, 'n_days': 2},
#  'FENY_5': {'model_accuracy': 0.37911152839660645, 'n_days': 5},
#  'FENY_10': {'model_accuracy': 0.6817408800125122, 'n_days': 10},
#  ...}

# %%
# ## EYEG messes up when predicting for n_days = 10 
# ## Adding try loop to code and continuing 

# for index in range(235,len(symbol_list)):
#     symbol = symbol_list[index] 
    
#     try:
#         i = 1
#         mean_squared_model(symbol,
#                            export_path='../Model_Data/Date_Test_NN_noFTD_all/',
#                            n_days=i,
#                            epochs_value=200,
#                            validation_split_value=0.1,
#                            num_of_inputs=19
#                           )
#         i = 2
#         mean_squared_model(symbol,
#                            export_path='../Model_Data/Date_Test_NN_noFTD_all/',
#                            n_days=i,
#                            epochs_value=200,
#                            validation_split_value=0.1,
#                            num_of_inputs=19
#                           )
#         i = 5
#         mean_squared_model(symbol,
#                            export_path='../Model_Data/Date_Test_NN_noFTD_all/',
#                            n_days=i,
#                            epochs_value=200,
#                            validation_split_value=0.1,
#                            num_of_inputs=19
#                           )
#         i = 10
#         mean_squared_model(symbol,
#                            export_path='../Model_Data/Date_Test_NN_noFTD_all/',
#                            n_days=i,
#                            epochs_value=200,
#                            validation_split_value=0.1,
#                            num_of_inputs=19
#                           )
#     except: 
#         continue

# ## Export symbol_accuracy_dict
# path = Path('../Resources/NN_noFTDall_symbol_list.pkl')
# save_obj(symbol_accuracy_dict,path)

# %%
# ## load model data 
# file_path = Path('../Model_Data/Date_Test_NN/'+symbol+'_NN_model_data.json')
# with open(file_path, "r") as json_file:
#     model_json = json_file.read()
# loaded_model = model_from_json(model_json)

# # load weights into new model
# file_path = Path('../Model_Data/Date_Test_NN/'+symbol+'_NN_model_weights.h5')
# loaded_model.load_weights(file_path)

# # Load model summary
# file_path = Path('../Model_Data/Date_Test_NN/'+symbol+'_model_summary.pkl')
# model_summary = load_obj(file_path)

# X , y, features, close_df = prepare_data(symbol,n_days,return_data=True)


# close_df["predicted"] = loaded_model.predict(X)

# %%
# export_path='../Model_Data/Date_Test_NN/'
# model_type = 'NN'

# model_summary_list = [] 

# for i in range(1,11):
#     # Load model summary
#     n_days_string = str(i)
#     file_path = Path('_model_summary.pkl')
#     model_summary = load_obj(file_path)
    
#     model_summary_list.append(model_summary)
# model_summary_list

# %%
# n_days = 1
# model_type = 'NN'

# export_path='../Model_Data/Date_Test_NN_noFTD/'
# export_path_prefix = export_path+symbol+'_'+model_type+'_'+n_days_string
# n_days_string = str(n_days)

# file_path = Path(export_path_prefix+'_model_data.json')
# with open(file_path, "r") as json_file:
#     model_json = json_file.read()
# loaded_model = model_from_json(model_json)

# # load weights into new model
# file_path = Path(export_path_prefix+'_model_weights.h5')
# loaded_model.load_weights(file_path)

# X , y, features, close_df = prepare_data(symbol,n_days,return_data=True)


# close_df["predicted"] = loaded_model.predict(X)
# close_df.set_index('Close_Date',inplace=True)
# close_df[['close','predicted']].tail(30).plot(use_index=True)
